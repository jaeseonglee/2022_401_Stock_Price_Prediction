# %% [markdown]
# # 라이브러리

# %%
import re,pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from datetime import timedelta
from konlpy.tag import *

from sklearn.metrics import accuracy_score, f1_score, mean_squared_error, r2_score, confusion_matrix, classification_report, log_loss
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 종목 선택, 뉴스 & 토론방 & 유튜브 데이터 통합

# %%
# LG화학, 삼성SDI, SK이노베이션, 고려아연, 포스코케미칼
stock_name = '삼성SDI'

# %%
naver_news = pd.read_csv('./data/refined_naver_news.csv', index_col=0)
daum_news = pd.read_csv('./data/refined_daum_news.csv', index_col=0)
naver_talks = pd.read_csv(f'./data/refined_naver_talks_{stock_name}.csv', index_col=0)
daum_talks = pd.read_csv(f'./data/refined_daum_talks_{stock_name}.csv', index_col=0)
youtube = pd.read_csv(f'./data/refined_youtube_{stock_name}.csv', index_col=0)

# %%
# 데이터 통합
news_df = pd.concat([naver_news, daum_news, naver_talks, daum_talks ,youtube])

# 'Date' 타입이 int 이므로 datetime으로 변환
news_df['Date'] = pd.to_datetime(news_df['Date'].astype(str))

# 합쳐진 데이터들의 인덱스 재설정
news_df.sort_values('Date', ignore_index=True, inplace=True)

# %%
# 2021년 주식 데이터가 1월 4일부터 있어서 슬라이싱
news_df = news_df[news_df[news_df['Date']== '2021-01-04'].index[0] : ]
news_df.head(2)
# Out:
#           Date                         Title
# 639 2021-01-04  비올  일본 최대 병원체인과 실펌엑스 총판계약 체결
# 640 2021-01-04      환율 하락 전환  1086 2 감소0 1원

# %% [markdown]
# # 주가 데이터

# %%
stock_df = pd.read_csv(f'./data/{stock_name}_주가_데이터.csv', usecols = ['일자','등락률'])
stock_df['일자'] = pd.to_datetime(stock_df['일자'])
stock_df.head(2)
# Out:
#           일자   등락률
# 0 2021-01-04  6.85
# 1 2021-01-05  2.24

# %%
start = str(stock_df.iloc[0, 0])
end = str(stock_df.iloc[-1, 0])
print(start)
print(end)
# Out:
# 2021-01-04 00:00:00
# 2022-06-30 00:00:00

# %% [markdown]
# # 데이터 프레임 합치기

# %%
## 뉴스일자 조정(예측대상(주가)의 일자와 맞추기 위해)
news_df['일자'] = news_df['Date'] + timedelta(days=1)

# %%
df = news_df.merge(stock_df)
df.columns = [df.columns[0], df.columns[1], '주가의 날짜', '등락률' ]
df.drop_duplicates('Title', inplace = True, ignore_index = True)  # 기사제목 중복 제거
df['Title'] = df['Title'].astype(str)
print(len(df))
df.head()
# Out:
# 429241
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
# 3 2021-01-04                    韓증시 사상최고치 시작  개장식선 안정적 시장운영에 방점 2021-01-05
# 4 2021-01-04                  SK바이오팜  아벨 지분 매각으로 5천500만 달러 자본이득 2021-01-05
#
#     등락률
# 0  2.24
# 1  2.24
# 2  2.24
# 3  2.24
# 4  2.24

# %%
# multi 분류
stock_df['updown'] = 0

stock_df.loc[stock_df.query('등락률 >= 0').index, 'updown'] = 1
stock_df.loc[stock_df.query('등락률 < 0').index, 'updown'] = -1

stock_df['updown'].value_counts()
# Out:
#  1    193
# -1    176
# Name: updown, dtype: int64

# %%
# 뉴스 일자 열 추가 : 예측대상(= 익일의 주가)의 일자와 맞추기 위함

news_df['일자'] = news_df['Date'] + timedelta(days = 1)
news_df.head(3)
# Out:
#           Date                                              Title         일자
# 639 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 640 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 641 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05

# %% [markdown]
# # 뉴스 데이터 & 주가 데이터 합치기

# %%
df = news_df.merge(stock_df)

# df 칼럼명 : Date, Title, 주가의 날짜(구 : 일자), 등락률(y), updown
df.columns = [df.columns[0], df.columns[1], '주가의 날짜', '등락률(y)', 'updown']

# 기사 제목 중복 제거
df.drop_duplicates('Title', inplace = True, ignore_index = True)
df['Title'] = df['Title'].astype(str)
print(len(df))
df.head(3)
# Out:
# 429241
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
#
#    등락률(y)  updown
# 0    2.24       1
# 1    2.24       1
# 2    2.24       1

# %% [markdown]
# # 감성분석 모델 적용

# %% [markdown]
# ## 감성사전 만들기

# %%
df.isnull().sum()
# Out:
# Date      0
# Title     0
# 주가의 날짜    0
# 등락률(y)    0
# updown    0
# dtype: int64

# %%
df = df.dropna()
df.head(3)
# Out:
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
#
#    등락률(y)  updown
# 0    2.24       1
# 1    2.24       1
# 2    2.24       1

# %% [markdown]
# ###  (필요시) Title 에서 종목명 제거하기

# %%
# stopstocks = pd.read_csv("./data/종목명.csv", encoding = 'cp949')
# stopstocks = stopstocks['한글 종목약명'].tolist()

# for i in tqdm(range(len(df['Title']))) :
#     for stopstock in stopstocks :
#         if stopstock in str(df['Title'][i]) :
#             df['Title'][i] = str(df['Title'][i]).replace(stopstock,'')

# %% [markdown]
# # 감성 사전 구축

# %%
okt = Okt()

# %%
# Title 전처리 및 df['noun'] 생성 -> Title 에서 명사만 생성
n_ = []
title_rename = []

for i in tqdm(range(len(df))) : 
    # 기사 제목 앞 뒤로 괄호/대괄호 지우기
    title_rename.append(re.sub(r'[\(\[].*?[\)\]]', '', df.iloc[i]['Title']))
    
    # 바뀌어진 기사 제목에서 okt로 명사만 뽑기
    n_.append(' '.join(okt.nouns(df.iloc[i]['Title'])))

df['nouns'] = n_
df['Title'] = title_rename
df = df[df['nouns'] != ''] 
df.head(3)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 429241/429241 [08:42<00:00, 821.00it/s]
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
#
#    등락률(y)  updown                          nouns
# 0    2.24       1  비올 일본 최대 병원체 인과 실펌 엑스 판 계약 체결
# 1    2.24       1                    환율 하락 전환 감소
# 2    2.24       1        코스피 오른 출발 원 달러 환율 오른 출발

# %%
#df.to_csv('./[Model1_binary]cleaned_df.csv', encoding = 'utf-8-sig')

# %%
# 윗부분 건너뛰고 여기부터 테스트하고 싶을 때
#df = pd.read_csv('./[Model1_binary]cleaned_df.csv', index_col = 0)

# %%
vocab = {}
cnt = 0

for i in tqdm(df['nouns']) : 
    i = i.split(' ')   
    
    for j in range(len(i)) : 
        if i[j] in vocab or len(i[j]) <= 1:    
            cnt += 1
        else :    
            vocab[i[j]] = 0     

print(len(vocab))
print(vocab)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████|
# %%
df['updown'].value_counts()
# Out:
#  1    241815
# -1    185858
# Name: updown, dtype: int64

# %% [markdown]
# # vocab score 생성

# %%
up = len(df[df['updown'] == 1])
down = len(df[df['updown'] == -1])
up_ratio = up / (up + down)
down_ratio = down / (up + down)

print('up_ratio : ', up_ratio)
print('down_ratio : ', down_ratio)
# Out:
# up_ratio :  0.5654203094420269
# down_ratio :  0.434579690557973

# %%
for i,w in tqdm(enumerate(df['nouns'])) :
    w = w.split(' ')
    
    if df.iloc[i]['updown'] == 1 :
        for j in range(len(w)) :
            noun = w[j]
            if len(noun) <= 1 :
                continue
            vocab[noun] +=  down_ratio
    else :
        for j in range(len(w)) :
            noun = w[j]
            if len(noun) <= 1 :
                continue
            vocab[noun] -=  up_ratio
# Out:
# 427673it [00:56, 7547.34it/s]

# %%
vocab
# Out:
# {'비올': 5.691593811159458,
#  '일본': -32.499811772077955,
#  '최대': 31.581949293019093,
#  '병원체': 0.434579690557973,
#  '인과': -1.6121452605144582,
#  '실펌': 0.869159381115946,
#  '엑스': -19.21951584504978,
#  '계약': 91.6659036226034,
#  '체결': 106.76766595036878,
#  '환율': 149.36162675687495,
#  '하락': 127.29222326415493,
#  '전환': 65.28212442683325,
#  '감소': 145.66774381359704,
#  '코스피': -277.7108842501306,
#  '오른': 36.842232266232635,
#  '출발': 94.460442908461,
#  '달러': 149.02081964489116,
#  '증시': -329.0985355632801,
#  '사상': 6.912346582546142,
#  '최고': -111.18072686376593,
#  '시작': -19.317202629109968,
#  '개장': 16.91207768551714,
#  '안정': 19.98160042836484,
#  '시장': -91.76427784780913,
#  '운영': -12.04178893687443,
#  '방점': 2.5514189579421593,
#  '바이오': -43.83417704649015,
#  '아벨': 3.9112172150217566,
#  '매각': -28.167424644527102,
#  '자본': -14.77082724417929,
#  '이득': -1.5700874266086469,
#  '대웅제약': -4.18217890771689,
#  '코로나': 53.53935366504849,
#  '치료': 13.81873534219173,
#  '시험': -5.523254916723811,
#  '주가': -17.847156589291927,
#  '상승': 495.3394977001674,
#  '코스닥': 132.11159226792185,
#  '포인트': 41.02864805587691,
#  '신년사': -38.34574312617334,
#  '영채': -21.836382002136986,
#  '투자': -341.830197370305,
#  '증권': 202.87952711539685,
#  '대표': 60.832575355468194,
#  '데이터': -63.826725091367145,
#  '산이': 3.995332882833378,
#  '경쟁력': -9.238184313716326,
#  '케이피': 7.009388013739446,
#  '에스': 65.27654305976833,
#  '올해': -295.5591935894573,
#  '사업': -19.30625501260413,
#  '시너지': -43.055951626593036,
#  '효과': -55.46193704068073,
#  '기관': -68.88057932113259,
#  '매도': 14.833543384776108,
#  '자산운용': 81.79513085932076,
#  '조직개편': 23.752427672544368,
#  '단행': 8.331849333486064,
#  '조직': -0.45786149698488326,
#  '확대': -129.04532668651686,
#  '대체': -35.56992608838972,
#  '신설': 27.855319367834962,
#  '제로': -35.182125128310055,
#  '단독주택': -0.2616812377681078,
#  '신축': -10.504478889244607,
#  '수주': -12.316503496827819,
#  '전이': 0.3411297884131099,
#  '주역': 12.116839267384183,
#  '화학': -93.63011459690344,
#  '스토리': 6.523470034348623,
#  '브레인': -14.135453956644437,
#  '콘텐츠': -13.37353071154818,
#  '사이클': -12.2615736789557,
#  '고도화': -2.8924949669490534,
#  '어가': 1.9719972970002593,
#  '일주일': 4.864546043355527,
#  '전주': 8.135561515456883,
#  '서울시장': 1.9018829806885125,
#  '당선': -87.52797581329683,
#  '유력': 5.215010066101868,
#  '닷컴버블': 3.0747814334783756,
#  '이후': -27.471593951452775,
#  '모주': 33.46312018761727,
#  '청약': 74.08063169756375,
#  ...}

# %% [markdown]
# # vocab 정규화

# %%
robustScaler = RobustScaler()

# %%
# scale 할 리스트
vocab_v = [v for v in vocab.values()]
vocab_v_arr = np.array(vocab_v)

# %%
scaled_list = robustScaler.fit_transform(vocab_v_arr.reshape(-1,1))

# %%
scaled_list = np.squeeze(scaled_list, axis = 1)

# %%
for idx, v in tqdm(enumerate(vocab_v)) :
    vocab_v[idx] = list(scaled_list)[idx]

for i, k in tqdm(enumerate(vocab.keys())) :
    vocab[k] = vocab_v[i]
# Out:
# 35683it [00:38, 917.94it/s]
# 35683it [00:00, 1555659.67it/s]

# %%
vocab
# Out:
# {'비올': 3.498509308605978,
#  '일본': -20.898392502927457,
#  '최대': 20.03742561478825,
#  '병원체': 0.1402967640943526,
#  '인과': -1.1671635637980071,
#  '실펌': 0.417908909495017,
#  '엑스': -12.414858817484372,
#  '계약': 58.41942051237612,
#  '체결': 68.06651799582976,
#  '환율': 95.27579881938586,
#  '하락': 81.17772984736237,
#  '전환': 41.56530214133347,
#  '감소': 92.91612396337575,
#  '코스피': -177.5407146952688,
#  '오른': 23.397726322199222,
#  '출발': 60.204589178581614,
#  '달러': 95.05808916663115,
#  '증시': -210.3674584159159,
#  '사상': 4.278333592233553,
#  '최고': -71.16023886911697,
#  '시작': -12.477261728364585,
#  '개장': 10.666222546181817,
#  '안정': 12.627052314604708,
#  '시장': -58.756893327447365,
#  '운영': -7.829683280357377,
#  '방점': 1.4925465430298934,
#  '바이오': -28.138853870425734,
#  '아벨': 2.361193927299668,
#  '매각': -18.130837296559225,
#  '자본': -9.573009523695557,
#  '이득': -1.1402967640943529,
#  '대웅제약': -2.808916664675104,
#  '코로나': 34.06394886837746,
#  '치료': 8.690176672324469,
#  '시험': -3.6656041631814507,
#  '주가': -11.538187390979747,
#  '상승': 316.2885637978929,
#  '코스닥': 84.25637203355244,
#  '포인트': 26.07203415147254,
#  '신년사': -24.632808952512864,
#  '영채': -14.08652881007566,
#  '투자': -218.5005212938103,
#  '증권': 129.46335856658092,
#  '대표': 38.72290317376735,
#  '데이터': -40.910214970246315,
#  '산이': 2.4149275267069754,
#  '경쟁력': -6.0387236216332525,
#  '케이피': 4.340324247783367,
#  '에스': 41.56173673015842,
#  '올해': -188.94232308866478,
#  '환경': 0.3046163635495321,
#  '우호': 7.289572031164101,
#  '뉴스': 13.486824259733726,
#  '새벽': -7.044686387209316,
#  '불안': -1.1461564658365886,
#  '여전': -2.531270164663172,
#  '앤트': -6.934306514829257,
#  '레터': -1.2417668427216166,
#  '날개': -20.58500376407041,
#  '코스트코': 2.107467198814615,
#  '비밀': -5.537301639461802,
#  '병기': -1.3880607270033223,
#  '호조': 0.05099269889837999,
#  '글로비스': -16.943250663193272,
#  '부진': 14.737638314653271,
#  '경쟁': -8.492374769973328,
#  '심화': -3.7014494658605024,
#  '본격': -5.193549398942453,
#  '동시': -5.086494455464514,
#  '스위스': 0.5403173768611139,
#  '협력': 16.564408921445533,
#  '공격': 7.749323363525524,
#  '행보': -8.591000884257847,
#  '체력': 3.9283781038644334,
#  '과도': -20.85065602370751,
#  '상태': -2.1850518605262557,
#  '베트남': -4.543092631980862,
#  '연초': -27.256673756661662,
#  '방위': 1.1582194154338825,
#  '우량': 11.483636749277046,
#  '자격': 1.3522497789355405,
#  '교체': -5.767108596419956,
#  '논의': 12.415030590541306,
#  '흑자': 118.8094663384528,
#  '진원': 22.24183555194435,
#  '생명과학': 40.02995124632577,
#  '연구': 7.1046232344718465,
#  '손실': -28.563378283112225,
#  '자체': -13.447722737375416,
#  '악재': 14.883760425877984,
#  '불가피': 10.743360597949541,
#  '국면': 2.426921767081686,
#  '비중': 3.3643814377559833,
#  '디스': -7.519378988122275,
#  '카운트': -3.9641546973209487,
#  '해소': -23.486412004397067,
#  '지주회사': -3.2029745118657895,
#  '컨트롤': 1.1044858160265754,
#  '타워': 1.6478189302869963,
#  '역할': -10.167129209186745,
#  '수익': -80.79027256650888,
#  '못처': 0.417908909495017,
#  '누가': -2.946232045981419,
#  '조선': -10.25958643022716,
#  '대한민국': 11.823926642449377,
#  '작작': 0.05671498219534918,
#  '어쩜': -0.026866799703654232,
#  '탄원서': 0.5552242908013288,
#  '손가락': 1.1373153813063122,
#  '꼬추에묶': 0.1402967640943526,
#  '재주': -6.146259529670439,
#  '부리고': -0.30447894510431867,
#  '왕서': 0.1402967640943526,
#  '방이': -0.08358178189900345,
#  '과열': 13.406017732954172,
#  '내일': 25.48370545850001,
#  '무궁': 0.1402967640943526,
#  '발전': 11.262773940683129,
#  '이백만': 0.1402967640943526,
#  '훨훨': 4.761248894677701,
#  '얼마': -3.492512188418618,
#  '갈기': 0.05671498219534918,
#  '조도': -0.026866799703654267,
#  '입성': -12.304341526658781,
#  '종합': 18.568043041844998,
#  '백만원': 0.026866799703654267,
#  '도전': -16.611870563773923,
#  '이주식': -2.528357491097675,
#  '조만간': 2.131352615730227,
#  '액면': -16.593982267045707,
#  '분할': -21.64744102956201,
#  '쌈지': 0.1402967640943526,
#  '야금': 0.08358178189900338,
#  '수고': 1.1940303635016611,
#  '재천': -0.22089716320531524,
#  '부산': 1.0926289940969383,
#  '중부': 6.023885416915611,
#  '경찰서': 2.277612145400664,
#  '장님': -0.3880607270033221,
#  '이슈': -18.92210614678577,
#  '퇴임': 0.6865769065315571,
#  '영풍': -11.456701240350801,
#  '제련소': -7.092172101822806e-17,
#  '법적': 6.597032359056465,
#  '구제': -7.062677747771438,
#  '절차': -9.916349508878175,
#  '검토': 2.334533255264257,
#  '선전': 8.722456563822028,
#  '수출': 14.940544117296623,
#  '휘파람': 0.8895514183973424,
#  '초읽기': 12.525410462920936,
#  '버킷': -21.155203678034482,
#  '스튜디오': -11.692367899050852,
#  '토지': -1.0775503071003798,
#  '건물': 1.185120569748806,
#  '양수': 3.191083335324885,
#  '계룡': -2.6746170207681152,
#  '제로': -22.61187056377373,
#  '단독주택': -0.30447894510431867,
#  '신축': -6.847640286308208,
#  '수주': -8.0051726095148,
#  '전이': 0.08060039911096223,
#  '주역': 7.6029951246325504,
#  '화학': -59.94880117343626,
#  '스토리': 4.029916891714234,
#  '브레인': -9.167129209186717,
#  '콘텐츠': -8.680408013287684,
#  '사이클': -7.970083108285768,
#  '고도화': -1.985058731448514,
#  '어가': 1.1224084673660946,
#  '일주일': 2.9701861721195724,
#  '전주': 5.059730719594664,
#  '서울시장': 1.0776190163229187,
#  '당선': -56.05071786200814,
#  '유력': 3.194064718112923,
#  '닷컴버블': 1.8268736706259074,
#  '이후': -17.68633642425206,
#  '모주': 21.239129006044685,
#  '청약': 47.185842016574135,
#  ...}

# %% [markdown]
# # sent_score 설정

# %%
total = []

for i,w  in tqdm(enumerate(df['nouns'])) :
    sent_score = 0
    w = w.split(' ')
    
    for j in w:
        if len(j) <= 1 :
            continue
        elif j not in vocab :
            continue
        else :
            sent_score += vocab[j]
            
    total.append(sent_score / len(w))

df['sent_score'] = total
df.head()
# Out:
# 427673it [00:02, 207101.95it/s]
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
# 3 2021-01-04                    韓증시 사상최고치 시작  개장식선 안정적 시장운영에 방점 2021-01-05
# 4 2021-01-04                  SK바이오팜  아벨 지분 매각으로 5천500만 달러 자본이득 2021-01-05
#
#    등락률(y)  updown                           nouns  sent_score
# 0    2.24       1   비올 일본 최대 병원체 인과 실펌 엑스 판 계약 체결   11.609966
# 1    2.24       1                     환율 하락 전환 감소   77.733739
# 2    2.24       1         코스피 오른 출발 원 달러 환율 오른 출발   22.499726
# 3    2.24       1  증시 사상 최고 치 시작 개장 선 안정 시장 운영 방점  -30.138853
# 4    2.24       1            바이오 아벨 분 매각 달러 자본 이득    5.776612

# %%
desc = df['sent_score'].describe()
desc
# Out:
# count    427673.000000
# mean          6.244156
# std          33.819992
# min        -277.643876
# 25%         -11.326776
# 50%           2.077094
# 75%          21.889803
# max         316.288564
# Name: sent_score, dtype: float64

# %%
median = desc['50%']

# %%
df['sent_label'] = -1

# %%
df.loc[df.query(f'sent_score >= {median}').index, 'sent_label'] = 1

# %%
df.head()
# Out:
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
# 3 2021-01-04                    韓증시 사상최고치 시작  개장식선 안정적 시장운영에 방점 2021-01-05
# 4 2021-01-04                  SK바이오팜  아벨 지분 매각으로 5천500만 달러 자본이득 2021-01-05
#
#    등락률(y)  updown                           nouns  sent_score  sent_label
# 0    2.24       1   비올 일본 최대 병원체 인과 실펌 엑스 판 계약 체결   11.609966           1
# 1    2.24       1                     환율 하락 전환 감소   77.733739           1
# 2    2.24       1         코스피 오른 출발 원 달러 환율 오른 출발   22.499726           1
# 3    2.24       1  증시 사상 최고 치 시작 개장 선 안정 시장 운영 방점  -30.138853          -1
# 4    2.24       1            바이오 아벨 분 매각 달러 자본 이득    5.776612           1

# %%
print(df['sent_label'].value_counts())
# Out:
#  1    213837
# -1    213836
# Name: sent_label, dtype: int64

# %%
print(df['updown'].value_counts())
# Out:
#  1    241815
# -1    185858
# Name: updown, dtype: int64

# %%
print(accuracy_score(df['updown'], df[ 'sent_label']))

print(accuracy_score(df.loc[df.query('sent_label == 1').index, 'updown'],
               df.loc[df.query('sent_label == 1').index, 'sent_label']))

print(accuracy_score(df.loc[df.query('sent_label == -1').index, 'updown'],
               df.loc[df.query('sent_label == -1').index, 'sent_label']))
# Out:
# 0.5280412838781031
# 0.5934613747854675
# 0.46262088703492393

# %% [markdown]
# # 트레인 테스트 분리¶

# %%
# X : title, y : price
def data_split(X, y) :
    
    # 학습셋, 테스트셋 분리
    X_list = X.tolist()
    y_list = y.tolist()
    
    X_train, X_test, y_train, y_test = train_test_split(X_list, y_list, shuffle = True, test_size = 0.2)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = data_split(df['Title'], df['sent_label'])

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 342138
# 85535

# %% [markdown]
# # 토큰화 및 로지스틱 회귀

# %%
# 형태소 분석을 위한 함수
def tokenizer(text):
    okt = Okt()
    return okt.morphs(text)

# %%
tokenize_X_train = TfidfVectorizer(tokenizer = tokenizer).fit_transform(X_train)
tokenize_X_test = TfidfVectorizer(tokenizer = tokenizer).fit_transform(X_test)

# %% [markdown]
# # 로지스틱 회귀 그리드 서치

# %%
def parameter_serach(penalty, solvers) :
    best_score = 0
    Cs = [0.001, 0.01, 0.1, 1, 10, 100]
        
    kfold = KFold(3, shuffle = True)

    for s in solvers :
        scores_mean = []
        for C in tqdm(Cs) :
            lm = LogisticRegression(penalty = penalty, C = C, solver = s, multi_class = 'ovr')
            scores = cross_val_score(lm, tokenize_X_train, y_train, cv = kfold)

            score = np.mean(scores)
            scores_mean.append(score)

            if score > best_score:
                best_score = score
                best_parameters = {'penalty' : penalty, 'C': C, 'solver': s, 'best_score' : best_score}

    return best_parameters

# %%
# saga도 쓸 수 있지만 C값이 1 이상부터 시간이 너무 오래 걸림(분 단위)
l1_best_parameters = parameter_serach('l1', ['liblinear'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [01:56<00:00, 19.47s/it]

# %%
l2_best_parameters = parameter_serach('l2', ['liblinear', 'sag', 'saga'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:54<00:00,  9.09s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [02:01<00:00, 20.26s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [02:19<00:00, 23.31s/it]

# %% [markdown]
# ### 로지스틱 회귀의 최적 파라미터 확인

# %%
print(f"penalty\t\t:\t{l1_best_parameters['penalty']}")
print(f"C\t\t:\t{l1_best_parameters['C']}")
print(f"solver\t\t:\t{l1_best_parameters['solver']}")
print(f"best_score\t:\t{l1_best_parameters['best_score']}")
# Out:
# penalty		:	l1
# C		:	10
# solver		:	liblinear
# best_score	:	0.9845150202549848

# %%
print(f"penalty\t\t:\t{l2_best_parameters['penalty']}")
print(f"C\t\t:\t{l2_best_parameters['C']}")
print(f"solver\t\t:\t{l2_best_parameters['solver']}")
print(f"best_score\t:\t{l2_best_parameters['best_score']}")
# Out:
# penalty		:	l2
# C		:	100
# solver		:	saga
# best_score	:	0.9730547323010014

# %%
if l1_best_parameters['best_score'] > l2_best_parameters['best_score'] :
    best_param = l1_best_parameters
else :
    best_param = l2_best_parameters

# %%
best_param
# Out:
# {'penalty': 'l1',
#  'C': 10,
#  'solver': 'liblinear',
#  'best_score': 0.9845150202549848}

# %% [markdown]
# # 파이프 라인

# %%
# lowercase : 소문자로 반환 여부 lowercase = False, 
# tokenizer : 토크나이저 지정
tfidf = TfidfVectorizer(tokenizer = tokenizer)

# %%
logistic = LogisticRegression(penalty = best_param['penalty'],
                              C = best_param['C'],
                              solver = best_param['solver'],
                              multi_class = 'ovr' )

# %%
pipeline = Pipeline([('tfidf',tfidf), ('classfier', logistic)], verbose = True)

# %%
pipeline.fit(X_train, y_train)
# Out:
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=12.1min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=  15.3s
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(tokenizer=<function tokenizer at 0x000001D0EB7ABCA0>)),
#                 ('classfier',
#                  LogisticRegression(C=10, multi_class='ovr', penalty='l1',
#                                     solver='liblinear'))],
#          verbose=True)

# %% [markdown]
# ### 교차검증

# %%
score = cross_val_score(pipeline, X_train, y_train, cv = KFold(3, shuffle = True), scoring='f1_micro')
# Out:
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total= 5.9min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=   7.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total= 5.2min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=   6.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total= 5.0min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=   7.3s

# %%
print(score)
print(f"모델의 정확도\t:\t{score.mean()}")
# Out:
# [0.9851025  0.98439226 0.98390123]
# 모델의 정확도	:	0.9844653327020092

# %%
y_pred = pipeline.predict(X_test)

# %%
y_proba = pipeline.predict_proba(X_test)

# %% [markdown]
# # 평가

# %%
print(f'accuracy \t:\t {accuracy_score(y_test, y_pred)}')

#'micro', 'macro', 'weighted'
print(f'f1_score \t:\t {f1_score(y_test, y_pred, average = "micro")}')
print(f'f1_score \t:\t {f1_score(y_test, y_pred, average = "macro")}')
print(f'f1_score \t:\t {f1_score(y_test, y_pred, average = "weighted")}')

print(f'R2 \t\t:\t {r2_score(y_test, y_pred)}')

print(f'mse \t\t:\t {mean_squared_error(y_test, y_pred)}')

print(f'rmse \t\t:\t {mean_squared_error(y_test, y_pred, squared=False)}')

print(f'log_loss\t:\t {log_loss(y_test, y_proba)}')
# Out:
# accuracy 	:	 0.9866253580405682
# f1_score 	:	 0.9866253580405682
# f1_score 	:	 0.9866249064738917
# f1_score 	:	 0.986625261730573
# R2 		:	 0.946500314226054
# mse 		:	 0.053498567837727246
# rmse 		:	 0.231297574214965
# log_loss	:	 0.04273179060817917

# %%
print(confusion_matrix(y_pred, y_test))
print(classification_report(y_pred, y_test))
# Out:
# [[42444   625]
#  [  519 41947]]
#               precision    recall  f1-score   support
#
#           -1       0.99      0.99      0.99     43069
#            1       0.99      0.99      0.99     42466
#
#     accuracy                           0.99     85535
#    macro avg       0.99      0.99      0.99     85535
# weighted avg       0.99      0.99      0.99     85535

# %% [markdown]
# # 모델 저장 및 사용

# %%
def save_model(model):
    with open('./[Model1]pipe_binary.dat', 'wb') as fp :     # 쓰기
        pickle.dump(model, fp)
    print('저장완료')     # 학습된 모델 저장 완료

# %%
save_model(pipeline)
# Out:
# 저장완료

# %%
with open('./[Model1]pipe_binary.dat','rb') as fp :     # 읽기
    pipeline = pickle.load(fp)

# %% [markdown]
# # Inference

# %%
# 모델 사용 함수

def model_prediction():  
    # 객체를 복원, 저장된 모델 불러오기
    with open('./[Model1]pipe_binary.dat','rb') as fp:     # 읽기
        pipe = pickle.load(fp)
    while True :
        text = input('뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) : \n')
        example = [text]
        # 예측 정확도
        r1 = np.max(pipe.predict_proba(example) * 100)     # 확률값을 구해서 *100
        # 예측 결과 
        r2 = pipe.predict(example)[0]     # 긍정('1'), 부정('-1)

        if text == 'q':
            print("예측을 종료합니다.")
            break
        if r2 == 1 :
            print(f'\n{stock_name} 주가가 상승할 것으로 예상됩니다.')
        elif r2 == -1 :
            print(f'\n{stock_name} 주가가 하락할 것으로 예상됩니다.')
        else : 
            # 이진 분류 모델이라 사실상 실행 되지 않을 라인
            print(f'\n모르겠어요.....')
        print('확률 : %.3f' % r1)
        print('------------------------------------------------\n')

# %%
model_prediction()
# Out:
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# [줌인 이종목] 현대중공업, 실적 증가 기대에 껑충
#
# 삼성SDI 주가가 상승할 것으로 예상됩니다.
# 확률 : 100.000
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# 닷새만에 반등했지만…불안한 개미들, 7100억 차익실현
#
# 삼성SDI 주가가 하락할 것으로 예상됩니다.
# 확률 : 99.999
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# 20년 만의 '1유로=1달러'.. 경기침체 공포에 달러 초강세
#
# 삼성SDI 주가가 상승할 것으로 예상됩니다.
# 확률 : 100.000
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# 블랙록 '극심한 변동성' 경고.."지금은 저가매수도 하지 말라"
#
# 삼성SDI 주가가 하락할 것으로 예상됩니다.
# 확률 : 100.000
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# q
# 예측을 종료합니다.

# %% [markdown]
# ```
# [줌인 이종목] 현대중공업, 실적 증가 기대에 껑충
# 닷새만에 반등했지만…불안한 개미들, 7100억 차익실현
# 주식거래 뚝…"증권사, 2분기 실적 쇼크"
# '현대차 효과' 부품株에도 볕드나.. 미래형 자동차 양산 기대감 호재 [현대차, 29년만에 국내공장 신설]
# 2차전지株, 실적 부진해도 상승하는 까닭
# 블랙록 '극심한 변동성' 경고.."지금은 저가매수도 하지 말라"
# 20년 만의 '1유로=1달러'.. 경기침체 공포에 달러 초강세
#
# ```
