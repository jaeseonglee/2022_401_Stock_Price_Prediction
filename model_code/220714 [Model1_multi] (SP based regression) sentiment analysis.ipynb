# %% [markdown]
# # 라이브러리

# %%
import re,pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from datetime import timedelta
from konlpy.tag import *

from sklearn.metrics import accuracy_score, f1_score, mean_squared_error, r2_score, confusion_matrix, classification_report, log_loss
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 종목 선택, 뉴스 & 토론방 & 유튜브 데이터 통합

# %%
# LG화학, 삼성SDI, SK이노베이션, 고려아연, 포스코케미칼
stock_name = '삼성SDI'

# %%
naver_news = pd.read_csv('./data/refined_naver_news.csv', index_col=0)
daum_news = pd.read_csv('./data/refined_daum_news.csv', index_col=0)
naver_talks = pd.read_csv(f'./data/refined_naver_talks_{stock_name}.csv', index_col=0)
daum_talks = pd.read_csv(f'./data/refined_daum_talks_{stock_name}.csv', index_col=0)
youtube = pd.read_csv(f'./data/refined_youtube_{stock_name}.csv', index_col=0)

# %%
# 데이터 통합
news_df = pd.concat([naver_news, daum_news, naver_talks, daum_talks ,youtube])

# 'Date' 타입이 int 이므로 datetime으로 변환
news_df['Date'] = pd.to_datetime(news_df['Date'].astype(str))

# 합쳐진 데이터들의 인덱스 재설정
news_df.sort_values('Date', ignore_index=True, inplace=True)

# %%
# 2021년 주식 데이터가 1월 4일부터 있어서 슬라이싱
news_df = news_df[news_df[news_df['Date']== '2021-01-04'].index[0] : ]
news_df.head(2)
# Out:
#           Date                         Title
# 639 2021-01-04  비올  일본 최대 병원체인과 실펌엑스 총판계약 체결
# 640 2021-01-04      환율 하락 전환  1086 2 감소0 1원

# %% [markdown]
# # 주가 데이터

# %%
stock_df = pd.read_csv(f'./data/{stock_name}_주가_데이터.csv', usecols = ['일자','등락률'])
stock_df['일자'] = pd.to_datetime(stock_df['일자'])
stock_df.head(2)
# Out:
#           일자   등락률
# 0 2021-01-04  6.85
# 1 2021-01-05  2.24

# %%
start = str(stock_df.iloc[0, 0])
end = str(stock_df.iloc[-1, 0])
print(start)
print(end)
# Out:
# 2021-01-04 00:00:00
# 2022-06-30 00:00:00

# %% [markdown]
# # 데이터 프레임 합치기

# %%
## 뉴스일자 조정(예측대상(주가)의 일자와 맞추기 위해)
news_df['일자'] = news_df['Date'] + timedelta(days=1)

# %%
df = news_df.merge(stock_df)
df.columns = [df.columns[0], df.columns[1], '주가의 날짜', '등락률' ]
df.drop_duplicates('Title', inplace = True, ignore_index = True)  # 기사제목 중복 제거
df['Title'] = df['Title'].astype(str)
print(len(df))
df.head()
# Out:
# 429241
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
# 3 2021-01-04                    韓증시 사상최고치 시작  개장식선 안정적 시장운영에 방점 2021-01-05
# 4 2021-01-04                  SK바이오팜  아벨 지분 매각으로 5천500만 달러 자본이득 2021-01-05
#
#     등락률
# 0  2.24
# 1  2.24
# 2  2.24
# 3  2.24
# 4  2.24

# %%
# multi 분류
stock_df['updown'] = 0

stock_df.loc[stock_df.query('등락률 > 1').index, 'updown'] = 1
stock_df.loc[stock_df.query('등락률 < -1').index, 'updown'] = -1

stock_df['updown'].value_counts()
# Out:
#  0    149
#  1    111
# -1    109
# Name: updown, dtype: int64

# %%
# 뉴스 일자 열 추가 : 예측대상(= 익일의 주가)의 일자와 맞추기 위함

news_df['일자'] = news_df['Date'] + timedelta(days = 1)
news_df.head(3)
# Out:
#           Date                                              Title         일자
# 639 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 640 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 641 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05

# %% [markdown]
# # 뉴스 데이터 & 주가 데이터 합치기

# %%
df = news_df.merge(stock_df)

# df 칼럼명 : Date, Title, 주가의 날짜(구 : 일자), 등락률(y), updown
df.columns = [df.columns[0], df.columns[1], '주가의 날짜', '등락률(y)', 'updown']

# 기사 제목 중복 제거
df.drop_duplicates('Title', inplace = True, ignore_index = True)
df['Title'] = df['Title'].astype(str)
print(len(df))
df.head(3)
# Out:
# 429241
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
#
#    등락률(y)  updown
# 0    2.24       1
# 1    2.24       1
# 2    2.24       1

# %% [markdown]
# # 감성분석 모델 적용

# %% [markdown]
# ## 감성사전 만들기

# %%
df.isnull().sum()
# Out:
# Date      0
# Title     0
# 주가의 날짜    0
# 등락률(y)    0
# updown    0
# dtype: int64

# %%
df = df.dropna()
df.head(3)
# Out:
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
#
#    등락률(y)  updown
# 0    2.24       1
# 1    2.24       1
# 2    2.24       1

# %% [markdown]
# ###  (필요시) Title 에서 종목명 제거하기

# %%
# stopstocks = pd.read_csv("./data/종목명.csv", encoding = 'cp949')
# stopstocks = stopstocks['한글 종목약명'].tolist()

# for i in tqdm(range(len(df['Title']))) :
#     for stopstock in stopstocks :
#         if stopstock in str(df['Title'][i]) :
#             df['Title'][i] = str(df['Title'][i]).replace(stopstock,'')

# %% [markdown]
# # 감성 사전 구축

# %%
okt = Okt()

# %%
# Title 전처리 및 df['noun'] 생성 -> Title 에서 명사만 생성
n_ = []
title_rename = []

for i in tqdm(range(len(df))) : 
    # 기사 제목 앞 뒤로 괄호/대괄호 지우기
    title_rename.append(re.sub(r'[\(\[].*?[\)\]]', '', df.iloc[i]['Title']))
    
    # 바뀌어진 기사 제목에서 okt로 명사만 뽑기
    n_.append(' '.join(okt.nouns(df.iloc[i]['Title'])))

df['nouns'] = n_
df['Title'] = title_rename
df = df[df['nouns'] != ''] 
df.head(3)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 429241/429241 [08:54<00:00, 803.23it/s]
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
#
#    등락률(y)  updown                          nouns
# 0    2.24       1  비올 일본 최대 병원체 인과 실펌 엑스 판 계약 체결
# 1    2.24       1                    환율 하락 전환 감소
# 2    2.24       1        코스피 오른 출발 원 달러 환율 오른 출발

# %%
#df.to_csv('./[Model1_multi]cleaned_df.csv', encoding = 'utf-8-sig')

# %%
# 윗부분 건너뛰고 여기부터 테스트하고 싶을 때
#df = pd.read_csv('./[Model1_multi]cleaned_df.csv', index_col = 0)

# %%
vocab = {}
cnt = 0

for i in tqdm(df['nouns']) : 
    i = i.split(' ')   
    
    for j in range(len(i)) : 
        if i[j] in vocab or len(i[j]) <= 1:    
            cnt += 1
        else :    
            vocab[i[j]] = 0     

print(len(vocab))
print(vocab)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 427673/427673 [00:01<00:00, 277273.35it/s]
# 35683
# {'비올': 0, '일본': 0, '최대': 0, '병원체': 0, '인과': 0, '실펌': 0, '엑스': 0, '계약': 0, '체결': 0, '환율': 0, '하락': 0, '전환': 0, '감소': 0, '코스피': 0, '오른': 0, '출발': 0, '달러': 0, '증시': 0, '사상': 0, '최고': 0, '시작': 0, '개장': 0, '안정': 0, '시장': 0, '운영': 0, '방점': 0, '바이오': 0, '아벨': 0, '매각': 0, '자본': 0, '이득': 0, '대웅제약': 0, '코로나': 0, '치료': 0, '시험': 0, '주가': 0, '상승': 0, '코스닥': 0, '포인트': 0, '신년사': 0, '영채': 0, '투자': 0, '증권': 0, '대표': 0, '데이터': 0, '산이': 0, '경쟁력': 0, '케이피': 0, '에스': 0, '올해': 0, '사업': 0, '시너지': 0, '효과': 0, '기관': 0, '매도': 0, '자산운용': 0, '조직개편': 0, '단행': 0, '조직': 0, '확대': 0, '대체': 0, '신설': 0, '가치투자': 0, '대가': 0, '방천': 0, '주식': 0, '펀드': 0, '가계': 0, '연금': 0, '자산': 0, '변화': 0, '개인': 0, '매수': 0, '스팟': 0, '외국인': 0, '중립': 0, '윤관석': 0, '정무': 0, '위원장': 0, '자본시장': 0, '질서': 0, '유지': 0, '삼성': 0, '전자': 0, '반도체': 0, '업황': 0, '회복': 0, '기대': 0, '목표': 0, '하이': 0, '성수': 0, '금융': 0, '사모펀드': 0, '사태': 0, '신뢰': 0, '만전': 0, '손병두': 0, '거래소': 0, '이사장': 0, '공매도': 0, '적법': 0, '사전': 0, '사후': 0, '관리': 0, '강화': 0, '증가': 0, '속보': 0, '새해': 0, '거래': 0, '최석': 0, '대표이사': 0, '주주': 0, '가치': 0, '역량': 0, '집중': 0, '위지트': 0, '신고': 0, '경신': 0, '전일': 0, '대량': 0, '베스트': 0, '넘버원': 0, '중형': 0, '증권사': 0, '달성': 0, '에프': 0, '최근': 0, '프로그램': 0, '우위': 0, '동양': 0, '엔피': 0, '단기간': 0, '골든': 0, '크로스': 0, '형성': 0, '킨스': 0, '단기': 0, '중기': 0, '이평': 0, '배열': 0, '상승세': 0, '세진': 0, '티에스': 0, '미니': 0, '핵심': 0, '공급': 0, '업체': 0, '델타': 0, '테크': 0, '실리콘': 0, '웍스': 0, '종가': 0, '기준': 0, '현우': 0, '산업': 0, '이노베이션': 0, '연속': 0, '이엔드디': 0, '경창': 0, '인트론': 0, '메기': 0, '아이': 0, '동서': 0, '하이닉스': 0, '삼진': 0, '앤디': 0, '서울': 0, '잠시': 0, '대위': 0, '업종': 0, '대비': 0, '현대': 0, '모비스': 0, '공영': 0, '피지': 0, '인텍': 0, '플러스': 0, '규모': 0, '관련': 0, '장비': 0, '납품': 0, '소식': 0, '강세': 0, '하나': 0, '기술': 0, '각각': 0, '특징': 0, '중증': 0, '승인': 0, '급등': 0, '전시': 0, '한화': 0, '비대': 0, '국내': 0, '해외': 0, '이벤트': 0, '법무': 0, '법인': 0, '태평양': 0, '서동우': 0, '신임': 0, '업무': 0, '집행': 0, '변호사': 0, '취임': 0, '전망': 0, '상향': 0, '조정': 0, '간다': 0, '지수선물': 0, '보합': 0, '미국': 0, '중국': 0, '통신사': 0, '석유': 0, '회사': 0, '출하': 0, '고비': 0, '물량': 0, '해제': 0, '평가': 0, '분석': 0, '박학주': 0, '선임': 0, '그린': 0, '스마트': 0, '수혜': 0, '와우': 0, '공개방송': 0, '뉴욕증시': 0, '마감': 0, '영향': 0, '관심': 0, '종목': 0, '공시': 0, '두산': 0, '퓨얼': 0, '연료': 0, '전지': 0, '시스템': 0, '글로벌': 0, '세계': 0, '경제': 0, '지옥': 0, '상춘': 0, '금세': 0, '경기': 0, '반등': 0, '진정': 0, '건설': 0, '밸류': 0, '매력': 0, '오늘': 0, '주식시장': 0, '오전': 0, '리츠': 0, '유럽': 0, '주요': 0, '개국': 0, '서비스': 0, '개시': 0, '길라잡이': 0, '자율': 0, '주행': 0, '주목': 0, '바이두': 0, '김원규': 0, '사장': 0, '현재': 0, '사이언티': 0, '메디프론': 0, '확장': 0, '마켓': 0, '브리핑': 0, '차입': 0, '포스코에너지': 0, '정책': 0, '지원': 0, '실적': 0, '신호': 0, '전기차': 0, '확보': 0, '미래에셋': 0, '대우': 0, '회장': 0, '테라': 0, '퓨틱스': 0, '양도': 0, '결정': 0, '워드': 0, '계속': 0, '시대': 0, '외환': 0, '조지아주': 0, '상원': 0, '선거': 0, '촉각': 0, '예고': 0, '검증': 0, '시간': 0, '필요': 0, '의견': 0, '보유': 0, '하향': 0, '유진': 0, '호텔': 0, '신라': 0, '닛케이지수': 0, '에이': 0, '피티': 0, '차세대': 0, '공정': 0, '진입': 0, '운용': 0, '이현승': 0, '단독': 0, '체제': 0, '역대': 0, '사주': 0, '성과급': 0, '급증': 0, '국채선물': 0, '연내': 0, '대화면': 0, '제품': 0, '항암제': 0, '속도': 0, '최현': 0, '수석': 0, '부회장': 0, '비즈니스': 0, '디지털': 0, '가속': 0, '보호': 0, '예수': 0, '티어': 0, '도약': 0, '큐렉소': 0, '의료': 0, '의료로봇': 0, '금융투자': 0, '협회': 0, '이해': 0, '과정': 0, '개설': 0, '기업가': 0, '치평': 0, '실무': 0, '신축년': 0, '진검': 0, '승부': 0, '선택': 0, '고객': 0, '기업': 0, '크기': 0, '활용': 0, '이진우': 0, '주간': 0, '호재': 0, '재는': 0, '한미': 0, '특별': 0, '지급': 0, '유안': 0, '접점': 0, '드론': 0, '신규': 0, '특허': 0, '서브': 0, '스트레이트': 0, '검사': 0, '장마': 0, '친환경': 0, '아스콘': 0, '설비': 0, '순풍': 0, '매출': 0, '성과': 0, '엠디': 0, '중국군': 0, '통제': 0, '자금': 0, '조치': 0, '유입': 0, '정상화': 0, '무엇': 0, '중요': 0, '포비': 0, '스티': 0, '적격성': 0, '실질': 0, '심사': 0, '대상': 0, '정지': 0, '안랩': 0, '미래': 0, '성장': 0, '제도': 0, '개선': 0, '도입': 0, '중점': 0, '추진': 0, '나인': 0, '대감': 0, '한국': 0, '정보': 0, '인증': 0, '전자서명': 0, '공동': 0, '진출': 0, '신청': 0, '상한': 0, '현대차': 0, '급락': 0, '의무': 0, '모두': 0, '고통': 0, '텍티앤': 0, '티머니': 0, '단말기': 0, '통합': 0, '보수': 0, '동학': 0, '개미': 0, '그룹': 0, '공략': 0, '독보': 0, '입지': 0, '패스': 0, '아크': 0, '인 ...

# %%
df['updown'].value_counts()
# Out:
#  0    169318
#  1    141094
# -1    117261
# Name: updown, dtype: int64

# %% [markdown]
# # vocab score 생성

# %%
up = len(df[df['updown'] == 1])
mid = len(df[df['updown'] == 0])
down = len(df[df['updown'] == -1])

up_ratio = up / (up + mid + down)
mid_ratio = mid / (up + mid + down)
down_ratio = down / (up + mid + down)

print('up_ratio : ', up_ratio)
print('mid_ratio : ', mid_ratio)
print('down_ratio : ', down_ratio)
# Out:
# up_ratio :  0.32991093662681537
# mid_ratio :  0.3959052827744562
# down_ratio :  0.27418378059872844

# %%
for i,w in tqdm(enumerate(df['nouns'])) :
    w = w.split(' ')
    
    if df.iloc[i]['updown'] == 1 :
        for j in range(len(w)) :
            noun = w[j]
            if len(noun) <= 1 :
                continue
            vocab[noun] += down_ratio
            
    elif df.iloc[i]['updown'] == 0 : 
        for j in range(len(w)) : 
            noun = w[j] 
            if len(noun) <= 1 : 
                continue
            vocab[noun] += mid_ratio  # 더하는 게 맞을까?  
    else :
        for j in range(len(w)) :
            noun = w[j]
            if len(noun) <= 1 :
                continue
            vocab[noun] -= up_ratio
# Out:
# 427673it [01:30, 4732.27it/s]

# %%
vocab
# Out:
# {'비올': 6.096795916506303,
#  '일본': 109.09647324006839,
#  '최대': 1500.071281095726,
#  '병원체': 0.27418378059872844,
#  '인과': 2.6144227014564874,
#  '실펌': 0.5483675611974569,
#  '엑스': 82.75071842271967,
#  '계약': 1471.9016047308355,
#  '체결': 897.5448952821741,
#  '환율': 1217.0549742444432,
#  '하락': 4164.125598297248,
#  '전환': 995.9352846684793,
#  '감소': 5529.088591048276,
#  '코스피': 5398.043547288322,
#  '오른': 776.9277976398063,
#  '출발': 1623.6671358726467,
#  '달러': 1413.8595562498679,
#  '증시': 2539.5221652997707,
#  '사상': 723.7538937459418,
#  '최고': 1094.3558630075463,
#  '시작': 334.75225698138456,
#  '개장': 587.0853642853301,
#  '안정': 180.65196306523754,
#  '시장': 1267.6977644135663,
#  '운영': 160.9958356033688,
#  '방점': 13.83430331117464,
#  '바이오': 1453.0080014404705,
#  '아벨': 2.589375527564284,
#  '매각': 545.4404720428896,
#  '자본': 124.52781447507725,
#  '이득': 1.269792575168411,
#  '대웅제약': 47.91259677370314,
#  '코로나': 1315.253640047505,
#  '치료': 627.3023431453529,
#  '시험': 63.27331161892357,
#  '주가': 2011.1156982088883,
#  '상승': 7850.834172365616,
#  '코스닥': 2811.3272874376926,
#  '포인트': 384.9892207364015,
#  '신년사': 71.51384352063374,
#  '영채': 33.60452261424028,
#  '투자': 3783.411433503231,
#  '증권': 3687.060555612663,
#  '대표': 542.2710762662098,
#  '데이터': 236.92039946407553,
#  '산이': 3.772639376345947,
#  '경쟁력': 97.45806024696408,
#  '케이피': 27.75525693695884,
#  '에스': 550.1535378665474,
#  '올해': 891.7074891331008,
#  '사업': 1380.7054618833756,
#  '시너지': 63.23836201958013,
#  '효과': 442.5826905135426,
#  '기관': 1598.3883270630897,
#  '매도': 1071.4504282478092,
#  '자산운용': 440.2018691850968,
#  '조직개편': 52.030745452717134,
#  '단행': 43.58083863138419,
#  '조직': 63.35223640491672,
#  '확대': 848.1590841601345,
#  '대체': 82.52975053370167,
#  '신설': 118.94912935817715,
#  '가치투자': 3.9560856074617776,
#  '대가': 21.03122712913837,
#  '방천': 5.738931379815894,
#  '주식': 2153.840918178467,
#  '펀드': 919.8539585150821,
#  '가계': 46.73947852681835,
#  '연금': 293.27666230975433,
#  '자산': 831.9539437841836,
#  '변화': 100.22643000610229,
#  '개인': 673.2588613263065,
#  '매수': 1818.8586934412056,
#  '스팟': 120.63581521395969,
#  '외국인': 1459.1095229300129,
#  '중립': 99.24466356304886,
#  '윤관석': 0.6803562534927385,
#  '정무': 0.807892946246314,
#  '위원장': 43.597164188527096,
#  '자본시장': 59.83040313510519,
#  '질서': 7.249318989040694,
#  '유지': 301.0370960991215,
#  '삼성': 2266.2440439311563,
#  '전자': 1261.7258466165906,
#  '반도체': 862.2075674639656,
#  '업황': 106.20144362632189,
#  '회복': 912.4071241345922,
#  '기대': 1091.4447603660478,
#  '목표': 2267.811535916926,
#  '하이': 298.36522062416753,
#  '성수': 2.047190259848062,
#  '금융': 1099.2383877402376,
#  '사모펀드': 144.52866325440124,
#  '사태': 174.65411424148763,
#  '신뢰': 40.99597589747297,
#  '만전': 0.45750842349178167,
#  '손병두': 25.380250799091787,
#  '거래소': 711.2278586677472,
#  '이사장': 49.90826636238429,
#  '공매도': 624.3630180067548,
#  '적법': 1.7008906337318466,
#  '사전': 64.19320368599367,
#  '사후': 1.640833066384831,
#  '관리': 295.03664014328746,
#  '강화': 445.1049189450775,
#  '증가': 1999.215033448645,
#  '속보': 512.8132662103928,
#  '새해': 188.4221122212534,
#  '거래': 1662.5118279621786,
#  '최석': 7.752165790218229,
#  '대표이사': 144.97199495876453,
#  '주주': 804.9943788829621,
#  '가치': 424.5089706387786,
#  '역량': 44.59710339441568,
#  '집중': 158.08787788801064,
#  '위지트': 1.832818531915739,
#  '신고': 1549.3206351583074,
#  '경신': 1421.0103092784814,
#  '전일': 269.5649222653763,
#  '대량': 252.07467621289996,
#  '베스트': 198.85688130884893,
#  '넘버원': 4.960416018780705,
#  '중형': 12.856200882449896,
#  '증권사': 590.9092203622923,
#  '달성': 348.9251905076994,
#  '에프': 314.44487026302744,
#  '최근': 98.26946756049567,
#  '프로그램': 155.85630376479114,
#  '우위': 88.51823940253401,
#  '동양': 26.704346545140776,
#  '엔피': 21.743626555803143,
#  '단기간': 43.30831967414353,
#  '골든': 52.99461270643689,
#  '크로스': 43.880069585875106,
#  '형성': 58.451999541705845,
#  '킨스': -1.3445693321766863,
#  '단기': 444.83782235492504,
#  '중기': 295.7902579774722,
#  '이평': 304.89447545203814,
#  '배열': 292.7449195997868,
#  '상승세': 672.8155787248779,
#  '세진': 7.0879527115342835,
#  '티에스': 25.320887687555672,
#  '미니': 27.854959279636557,
#  '핵심': 166.4386224989643,
#  '공급': 1029.4295805440686,
#  '업체': 323.3276358339192,
#  '델타': 195.59338560068068,
#  '테크': 570.8715747779249,
#  '실리콘': 58.7984184178097,
#  '웍스': 27.302382895342937,
#  '종가': 155.8284366794244,
#  '기준': 226.70805732417,
#  '현우': 4.406233267005399,
#  '산업': 531.5688271179126,
#  '이노베이션': 186.07451487468182,
#  '연속': 691.1396206915289,
#  '이엔드디': 4.954661622314248,
#  '경창': 0.7770913758876523,
#  '인트론': 4.859350485066865,
#  '메기': 2.9546008282028566,
#  '아이': 409.94570618205785,
#  '동서': 15.428313220614784,
#  '하이닉스': 356.21209896345795,
#  '삼진': 13.960476812892079,
#  '앤디': 87.97526147313476,
#  '서울': 141.4282968529679,
#  '잠시': 10.224393403371261,
#  '대위': 50.54001070911651,
#  '업종': 383.3969972385428,
#  '대비': 917.9162537733692,
#  '현대': 660.8469952510628,
#  '모비스': 36.281972441561564,
#  '공영': 19.951633607920062,
#  '피지': 10.03104474680421,
#  '인텍': 12.712521014887534,
#  '플러스': 224.7781973610669,
#  '규모': 1895.4525490271333,
#  '관련': 677.7405938649528,
#  '장비': 319.65633556478986,
#  '납품': 68.89615430480741,
#  '소식': 653.0797969476729,
#  '강세': 1941.0871436824063,
#  '하나': 635.7089996329082,
#  '기술': 769.6297264499068,
#  '각각': 32.226242947298516,
#  '특징': 4000.7692372457573,
#  '중증': 12.244927783610365,
#  '승인': 479.60119296751753,
#  '급등': 1370.5138318295699,
#  '전시': 120.77201272935132,
#  '한화': 427.8972509370433,
#  '비대': 104.14874682292285,
#  '국내': 932.6701428428255,
#  '해외': 654.2079789933122,
#  '이벤트': 328.113909458861,
#  '법무': 25.960841577560416,
#  '법인': 187.84670998636653,
#  '태평양': 22.997336750274158,
#  '서동우': 0.27418378059872844,
#  '신임': 95.82001435676295,
#  '업무': 206.24436660719604,
#  '집행': 13.758102569018837,
#  '변호사': 16.73193538053604,
#  '취임': 62.84024242821022,
#  '전망': 1281.9976103238835,
#  '상향': 360.036104687458,
#  '조정': 410.3189259083422,
#  '간다': 210.12824985444377,
#  '지수선물': 90.06963731636075,
#  '보합': 356.5961002915755,
#  '미국': 775.8887070261881,
#  '중국': 924.7863157132157,
#  '통신사': 14.931038433569547,
#  '석유': 103.24999473897076,
#  '회사': 411.0782350066482,
#  '출하': 13.549973928679142,
#  '고비': 7.483918788420129,
#  '물량': 116.97314537041093,
#  '해제': 120.05313171511867,
#  '평가': 560.5764637935976,
#  '분석': 217.7480645259337,
#  '박학주': 1.919286464191099,
#  '선임': 223.10114503370292,
#  '그린': 190.92575168411298,
#  '스마트': 152.2573882382088,
#  '수혜': 420.6973248252721,
#  '와우': 35.99894311775583,
#  '공개방송': 26.39911801773785,
#  '뉴욕증시': 767.0852614030072,
#  '마감': 3337.2705221055153,
#  '영향': 351.6778449890447,
#  '관심': 125.20496267007651,
#  '종목': 1481.7290944250626,
#  '공시': 1089.0601814938668,
#  '두산': 136.93035566893258,
#  '퓨얼': 45.99951832357883,
#  '연료': 46.4663563049338,
#  '전지': 68.27004042808393,
#  '시스템': 435.86820070474045,
#  '글로벌': 1109.1156046793394,
#  '세계': 353.4705908486143,
#  '경제': 266.8896306290079,
#  '지옥': 13.372950829255043,
#  '상춘': 56.46505390800898,
#  '금세': 30.4651123638855,
#  '경기': 297.9201329052784,
#  '반등': 764.5014882866359,
#  '진정': 51.174848540824286,
#  '건설': 583.500260713208,
#  '밸류': 132.83331189951159,
#  '매력': 161.58372635167385,
#  '오늘': 521.7051415450547,
#  '주식시장': 131.90769817126554,
#  '오전': 135.07024525747363,
#  '리츠': 482.4392631753662,
#  '유럽': 380.85901611745186,
#  '주요': 132.57118405884808,
#  '개국': 24.882732835601026,
#  '서비스': 603.2412216810523,
#  '개시': 186.67482866582543,
#  '길라잡이': 19.80374491726154,
#  '자율': 106.86578063146327,
#  '주행': 81.98013903145605,
#  '주목': 790.4752696569927,
#  '바이두': 11.828548914708193,
#  '김원규': 5.8886064820552155,
#  '사장': 161.67921753302042,
#  '현재': 182.37665693181395,
#  '사이언티': 9.302018130674606,
#  '메디프론': 10.807953740357698,
#  '확장': 180.0526219798757,
#  '마켓': 1054.1744861144537,
#  '브리핑': 189.95007400513754,
#  '차입': 36.886125614663506,
#  '포스코에너지': 1.0967351223949138,
#  '정책': 195.52361032845036,
#  '지원': 290.62417080339475,
#  '실적': 2616.4976231847313,
#  '신호': 101.4318930584813,
#  '전기차': 422.528172225038,
#  '확보': 238.88054190935415,
#  '미래에셋': 566.5888190276205,
#  '대우': 37.547918620067165,
#  '회장': 340.0321320261024,
#  '테라': 65.68826650267823,
#  '퓨틱스': 32.041676701592124,
#  '양도': 44.05330708274775,
#  '결정': 1122.9682841798203,
#  '워드': 34.600189864686335,
#  '계속': 131.6922718993234,
#  '시대': 353.35901027186424,
#  '외환': 213.46479436391675,
#  '조지아주': 7.290266161296133,
#  '상원': 19.692047428759814,
#  '선거': 28.786058507317495,
#  '촉각': 26.210102110724748,
#  '예고': 158.74830302590905,
#  '검증': 23.94860559352588,
#  '시간': 134.4278105000775,
#  '필요': 166.55719439852246,
#  '의견': 239.75457884879083,
#  '보유': 327.90256106885215,
#  '하향': 268.9558962104207,
#  '유진': 259.28271366207247,
#  '호텔': 209.69826713400087,
#  '신라': 167.0852076235811,
#  '닛케이지수': 120.90282061294451,
#  '에이': 241.06147453778723,
#  '피티': 5.859289690955473,
#  '차세대': 77.78679037488908,
#  '공정': 60.11015659160128,
#  '진입': 159.57915042567473,
#  '운용': 585.7487379376347,
#  '이현승': 4.148010278881295,
#  '단독': 327.534796444948,
#  '체제': 113.23763482847882,
#  '역대': 510.35331199303755,
#  '사주': 370.01981186560795,
#  '성과급': 22.43406761708127,
#  '급증': 239.23825679900182,
#  '국채선물': 87.99201258905727,
#  '연내': 94.34157872954307,
#  '대화면': 0.5483675611974569,
#  '제품': 178.29761055759772,
#  '항암제': 59.11473017936585,
#  '속도': 151.1260355458478,
#  '최현': 39.06333109642175,
#  '수석': 22.65697624119362,
#  '부회장': 70.64962015371546,
#  '비즈니스': 87.5183609907569,
#  '디지털': 274.75997549529615,
#  '가속': 117.29927304272121,
#  '보호': 85.83516144343878,
#  '예수': 28.76392009783161,
#  '티어': 39.11218617962768,
#  '도약': 156.86999179279326,
#  '큐렉소': 3.9809503990198145,
#  '의료': 106.37777460816977,
#  '의료로봇': 2.802077755668466,
#  '금융투자': 364.9238927872443,
#  '협회': 62.362566727382486,
#  '이해': 12.382914048817655,
#  '과정': 59.94049191789041,
#  '개설': 126.62512246506047,
#  '기업가': 9.112939091315097,
#  '치평': 1.888545687943826,
#  '실무': 22.703738604026906,
#  '신축년': 8.12308469321187,
#  '진검': 1.0923439169645968,
#  '승부': 39.71134254442056,
#  '선택': 63.339184376848465,
#  '고객': 305.41419028089183,
#  '기업': 1634.1813160991298,
#  '크기': 19.657037035305,
#  '활용': 101.9213230669225,
#  '이진우': 2.675965048062424,
#  '주간': 134.0268943795817,
#  '호재': 151.71849988191786,
#  '재는': 8.387122871913824,
#  '한미': 135.98102054607028,
#  '특별': 188.18497309860564,
#  '지급': 101.32365148138835,
#  '유안': 117.6285736999994,
#  '접점': 3.502907595288925,
#  '드론': 5.039586319454355,
#  '신규': 473.0107628959469,
#  '특허': 199.8699660722083,
#  '서브': 11.319886922952811,
#  '스트레이트': 1.527893975069738,
#  '검사': 160.1685282914735,
#  '장마': 42.318102849606895,
#  '친환경': 194.55713360441217,
#  '아스콘': 4.381246887224587,
#  '설비': 103.0444685542455,
#  '순풍': 6.873948086505348,
#  '매출': 1418.3735634469517,
#  '성과': 131.39016023924776,
#  '엠디': 5.117391090856803,
#  '중국군': 0.944272843971913,
#  '통제': 13.353475669495127,
#  '자금': 331.82673210607163,
#  '조치': 52.17769651111929,
#  '유입': 68.85142386823543,
#  '정상화': 112.06146050837867,
#  '무엇': 11.453178012172838,
#  '중요': 23.582080234197626,
#  '포비': 3.0205343802391083,
#  '스티': 12.755135348736044,
#  '적격성': 1.3812468872245858,
#  '실질': 29.52962426900923,
#  '심사': 152.1262810605285,
#  '대상': 244.5019348895057,
#  '정지': 141.51033850628843,
#  '안랩': 77.55427628117721,
#  '미래': 192.03826989311764,
#  '성장': 1195.3161691293103,
#  '제도': 77.73587998307087,
#  '개선': 688.4531195563154,
#  '도입': 219.6358526257195,
#  '중점': 8.392998856603057,
#  '추진': 495.47790250962277,
#  '나인': 51.441975528031804,
#  '대감': 851.8495182066997,
#  '한국': 1194.8828170121687,
#  '정보': 146.76847731794925,
#  '인증': 140.8906477612554,
#  '전자서명': 0.8284273264854218,
#  '공동': 222.13924657390072,
#  '진출': 342.4103485606981,
#  '신청': 199.1143490470509,
#  '상한': 295.00208570566576,
#  '현대차': 491.47139753970566,
#  '급락': 674.2173506393991,
#  '의무': 115.31407874707988,
#  '모두': 121.5577064720004,
#  '고통': 4.83869451660498,
#  '텍티앤': 3.929553654310654,
#  '티머니': 7.309498144610486,
#  '단말기': 7.183446231115831,
#  '통합': 125.1300596483757,
#  '보수': 82.54137857662273,
#  '동학': 294.52286209323455,
#  '개미': 1279.4374861168421,
#  '그룹': 907.441255351667,
#  '공략': 125.84357908963102,
#  '독보': 9.850507280094824,
#  '입지': 37.08843906442537,
#  '패스': 44.63396099356277,
#  '아크': 18.18072218727858,
#  '인포': 12.372586064586708,
#  '뱅크': 333.72847713089294,
#  '에코': 271.0174081599718,
#  '수도권매립지': 1.5439155616557507,
#  '공사': 418.4108372518212,
#  '러브콜': 43.50191150715611,
#  '선두': 37.69383617857565,
#  '선진': 30.330278039530217,
#  '국방': 1.5499131345677677,
#  '과학': 32.93721838881574,
#  '연구소': 65.90944950932119,
#  '화두': 6.467897201834114,
#  '리스크': 234.24897293025117,
#  '해성': 61.78593925732954,
#  '안철수': 65.79850727074168,
#  '지지율': 25.90511442153234,
#  '터치': 107.06851496353478,
#  '등락': 125.56401035370433,
#  '액티브': 109.48507855300618,
#  '김유상': 2.467654025388556,
#  '공세': 11.275911736303197,
#  '경보': 29.076385462725025,
#  '제약': 363.4219555595038,
#  '최초': 324.432547764296,
#  '난치': 0.356260507443771,
#  '혈액암': 5.030862364470052,
#  '치료법': 25.888971246723553,
#  '원료': 39.15134460206745,
#  '부각': 487.61809840695537,
#  '접근': 41.047007877513835,
#  '케이': 425.03269086427963,
#  '포스코': 117.98396438400279,
#  '케미칼': 206.40727845807336,
#  '티움': 7.294778954949227,
#  '거듭': 25.135019044924505,
#  '크리스탈': 27.190806995063987,
#  '지노': 71.23699649030907,
#  '믹스': 97.76668155342945,
#  '러시아': 197.17110502650348,
#  '아셀': 4.051275156486382,
#  '렉스': 61.11924297301893,
#  '품목': 41.12078620815424,
#  '허가': 232.54420550280125,
#  '아스': 55.852174441687815,
#  '결합': 54.00951427843229,
#  '백신': 553.3112705267778,
#  '접종': 89.36435313896342,
#  '아이디': 23.655189829612812,
#  '트론': 49.661369784858884,
#  '정일': 18.589801086343986,
#  '혁신': 186.28053208876753,
#  '일상': 31.526593916380047,
#  '확산': 214.66347419640658,
#  '악화': 67.73645285065909,
#  '훌쩍': 23.56926670610489,
#  '중반': 39.90078401021339,
#  '구조조정': 32.28914848494058,
#  '폭풍': 77.01372543976348,
#  '희비': 59.33385553916165,
#  '교차': 14.374010049734238,
#  '싸이': 8.1233886637688,
#  '토젠': 0.9501488286611497,
#  '도시바': 11.64528506592653,
#  '임원': 43.92101909636539,
#  '승진': 20.385822813224078,
#  '대상자': 28.663034608217032,
#  '스타트업': 78.34097312666434,
#  '연수': 6.309558938721876,
#  '잡기': 10.812588122233567,
#  '박차': 64.70898326525155,
#  '사후관리': -0.38557729854351336,
#  '푸드': 103.12690770752405,
#  '나무': 94.3104755268626,
#  '충성': 1.5791691315561185,
#  '지속': 612.77190517054,
#  '적정': 59.96108709224088,
#  '서희': 5.635017875806985,
#  '퓨쳐켐': 9.285874955865811,
#  '바이든': 147.7993022706594,
#  '정부': 214.5406958119851,
#  '출범': 117.31277868839015,
#  '재생': 34.82879442938876,
#  '에너지': 390.5675808386314,
#  '대원': 30.349145258176225,
#  '전선': 38.79069288919331,
#  '성도': 1.706888206643862,
#  '관계자': 152.2211619625273,
#  '변동': 229.12022503174157,
#  '네스': 5.533769959758975,
#  '미원': 14.05727272939838,
#  '홀딩스': 425.690391958339,
#  '엑시콘': 8.98670479548627,
#  '솔루션': 302.45739151174024,
#  '녹십자': 83.45200187994072,
#  '랩셀': 16.82991210574432,
#  '심텍': 11.399118017737825,
#  '넥스': 89.95460784290782,
#  '임상시험': 44.48719231749486,
#  '동일': 29.14089502961376,
#  '유동성': 90.2814603680844,
#  '이건': 10.3591692718502,
#  '전기': 238.30300954233428,
#  '처음': 31.27449008939068,
#  '콤보': 2.6598826673650198,
#  '기우': 4.498455595747219,
#  '엘오티베큠': 6.83863372249359,
#  '유니': 52.75228971667598,
#  '팬오션': 41.86138241132819,
#  '넷게임즈': 4.731813792313292,
#  '탄력': 54.484225097212054,
#  '월덱스': 0.1583382631122372,
#  '프로비': 149.62058395082133,
#  '동원': 62.02629345317543,
#  '개발': 742.6894823849321,
#  '폴리': 16.931403198237884,
#  '말레이시아': 14.381550857781514,
#  '공장': 252.76233477446453,
#  '약세': 537.0196154538635,
#  '기부': 58.9405550502366,
#  '전달': 80.12566610471077,
#  '사자': 247.16659924755376,
#  '듀오': 2.280059765287967,
#  '오토': 54.28993880838853,
#  '에버': 19.007725528616465,
#  '리서치': 98.81580553366676,
#  '알음': 33.68635616463975,
#  '플랫폼': 505.7118078531913,
#  '익일': 0.27418378059872844,
#  '배송': 106.756112730988,
#  '다이어트': 1.5997035117952265,
#  '혜주': 168.66123182898957,
#  '동화': 8.058635920434542,
#  '티스': 37.3642292125058,
#  '투명': 18.48558595001319,
#  '교정': 2.2801205593993545,
#  '상반기': 360.80374257902395,
#  '출시': 754.6422851103748,
#  '정문화': 0.27418378059872844,
#  '개편': 97.69432720793634,
#  '단자': 4.162790262653945,
#  '방전': 8.879763277083189,
#  '코러스': 5.488188405627666,
#  '호중': 0.22872381469019532,
#  '돌파': 1137.3070617037672,
#  '원년': 16.073415904207167,
#  '전략': 409.76522249475255,
#  '선포': 24.735903365421706,
#  '첫날': 483.44182120451177,
#  '질주': 64.14547095561315,
#  '배터리': 500.8129295045454,
#  '이노': 272.3663149181748,
#  '인구': 22.327065304566805,
#  '인팩': 2.385698886766291,
#  '신약': 147.41042572245516,
#  '완료': 211.7252293224018,
#  '상사': 32.31958529063092,
#  '네스엠': 0.5483675611974569,
#  '영업': 2657.342516362524,
#  '조회': 82.97835028164042,
#  '요구': 92.87598468923679,
#  '네트웍': 51.75289765778981,
#  '오늘이': 6.478042803730892,
#  '무덤': 9.412170045806022,
#  '트릭': 28.745172129173472,
#  '뉴딜': 65.07699574207383,
#  '수소': 114.68678873812436,
#  '인프라': 162.0662188167124,
#  '가능성': 337.81313059276494,
#  '왜팔': 0.27418378059872844,
#  '뼈속': 0.27418378059872844,
#  '발라': 0.944272843971913,
#  '눌림': 1.6143619073450977,
#  '수량': 3.4779820096195015,
#  '지금': 287.0795865065111,
#  '아침': 16.236023784526942,
#  '호가': 23.743565761691766,
#  '예수금': 1.9897936039918347,
#  '추가': 415.84866241263535,
#  '제일': 12.387305254247968,
#  '월달': 4.294778954949227,
#  '어어': 4.670149857484574,
#  '백만': 71.46993146633038,
#  '달뒤': 0.27418378059872844,
#  '가격': 625.1414608825025,
#  '손까락묵': 0.27418378059872844,
#  '저번': 6.665697857942869,
#  '평단': 32.37276844692091,
#  '어제': 63.422621956494716,
#  '수익률': 444.88365643844395,
#  '약주': 10.030923158581436,
#  '기회': 215.98645226609796,
#  '기억': 7.970744003011651,
#  '주님': 9.991217589139364,
#  '고체': 50.629508994021066,
#  '테마': 149.11613078216178,
#  '주민': 11.432704426045118,
#  '가면': 5.432765220156531,
#  '이제': 113.93807418284476,
#  '아무': 2.79768655023815,
#  '구매': 77.2527772386845,
#  '금사면': 0.4061724728940101,
#  '꼬리': 4.5191115642091075,
#  '분기': 417.8369455167794,
#  '이내': 6.742080982432845,
#  '만원': 139.48916812611412,
#  '도주': 27.205647772948023,
#  '상투': 1.3152525410769442,
#  '이번': 216.44814145386667,
#  '금요일': 10.944455226306074,
#  '야호': 0.34017812674636927,
#  '팔면': 2.37685568179427,
#  '어디': 97.79285108014706,
#  '안착': 86.26398206106053,
#  '서민': 13.290448543630282,
#  '살수': 1.030801570358662,
#  '주지': 2.5381611651892917,
#  '대세': 57.59462018878897,
#  '불변': 0.020534380239107808,
#  '탈출': 38.52641387228082,
#  '중이': 10.702253824767983,
#  '두리': 0.6700890633731846,
#  '가지': 87.36471790363166,
#  '역사상': 1.7009514278432352,
#  '일대': 2.884154482513511,
#  '여러분': 4.964868018322411,
#  '축하': 13.59667549740104,
#  '물반': 0.27418378059872844,
#  '기반': 142.5009200954928,
#  '보고': 537.0013023969162,
#  '반영': 114.38377218108157,
#  '난혼': 0.27418378059872844,
#  '시가': 9.72166819041651,
#  '시긴': 0.5483675611974569,
#  '최고점': 25.0166295276999,
#  '외로': 0.21845662457064152,
#  '동안': 85.21201244876315,
#  '가즈': 17.830033693967106,
#  '기네': 1.6803562534927385,
#  '장주': 223.4091887961114,
#  '안티': 18.38866844528412,
#  '사망': 6.37691647590566,
#  '욀케': 0.27418378059872844,
#  '아씨': -0.2229086241123477,
#  '바로': 22.451573982926185,
#  '갈라': 5.23899100480975,
#  '왜케올': 0.27418378059872844,
#  '일단': 15.12178463452213,
#  '현실': 62.37519319667111,
#  '정도': 23.43431079352682,
#  '장전': 9.3065309243277,
#  '대주': 33.54600828202856,
#  '안해': 39.78796650712111,
#  '악덕': 0.27418378059872844,
#  '흑우': 5.310861335646629,
#  '한번': 37.92398397841335,
#  '대박': 116.34158106777784,
#  '팔고': 65.93646547712842,
#  '나와라': 1.6803562534927385,
#  '합격': 10.371162079439193,
#  '통보': 30.77361208212817,
#  '당시': 1.4927011992807588,
#  '주변': 6.148071072992686,
#  '반응': 23.160187807039478,
#  '이재용': 94.9581479307784,
#  '역시': 37.26867489881279,
#  '방금': 4.822612135907575,
#  '잘못': 5.473530010077794,
#  '거지': 3.067418331295176,
#  '올린다': 12.458993202750689,
#  '사중': 2.5894363216756737,
#  '입질': 1.6246290974646516,
#  '정초': 1.4618996289220971,
#  '도마': 7.549730752233603,
#  '어우': 0.7360834095208255,
#  '대장': 50.56221225094865,
#  '래서': 0.6700890633731846,
#  '코인': 4.067418331295174,
#  '그냥': 19.85495927963653,
#  '사마': 5.208250228562477,
#  '쭉쭉': 13.727300998660178,
#  '설거지': 4.162790262653944,
#  '라면': 23.10000865146968,
#  '대금': 150.36372415373313,
#  '리차': 6.898873672174771,
#  '개월': 467.20014824410134,
#  '은행업': 6.010388778342333,
#  '이자': 72.12851173677082,
#  '이익': 1057.3077304389737,
#  '케이프': 34.951635946155086,
#  '초점': 15.429615617539547,
#  '금투': 448.122668487368,
#  '나스': 12.077746315526102,
#  '미디어': 130.82310784173828,
#  '빅데이터': 104.28376119137722,
#  '모멘텀': 171.94314113820462,
#  '클릭': 668.4544406591085,
#  '작년': 468.41016617836357,
#  '적자': 274.86304489645016,
#  '철강': 119.94098528548662,
#  '여력': 57.21937087447637,
#  '충분': 16.784756110392717,
#  '국민연금': 186.05726103822116,
#  '투자자': 335.1824805400384,
#  '온라인': 210.41139842823722,
#  '배너': 1.6246290974646518,
#  '광고': 114.58311373409057,
#  '가세': 21.555849913368384,
#  '신한': 184.31729615851168,
#  '환자': 78.51693700560915,
#  '계획': 277.5436373116846,
#  '서학': 304.148767867038,
#  '지난해': 667.0290899823262,
#  '상위': 237.4623158347598,
#  '테슬라': 639.2874088380657,
#  '지수': 501.40809684033854,
#  '린다': 34.56790585330376,
#  '제일제당': 68.79866159425542,
#  '장기': 284.1186560760195,
#  '성장동력': 34.86701521957192,
#  '굿모닝': 80.03586618748425,
#  '위험': 160.03505481991905,
#  '선호': 70.59047215980424,
#  '심리': 145.5539232076833,
#  '연말': 107.1388443974713,
#  '풍산': 15.80653209344518,
#  '기존': 36.49170511114792,
#  '정치': 85.80517357887922,
#  '상회': 155.25432748852336,
#  '통운': 36.19934856771407,
#  '택배': 33.406114017017686,
#  '단가': 23.74610976142987,
#  '인상': 617.7912868009046,
#  '여부': 66.29081798476848,
#  '일정': 31.095860622484885,
#  '대형주': 89.94631178493817,
#  '솔젠트': 4.426706853133119,
#  '신년': 10.183385437004436,
#  '간담': 3.790632095082003,
#  '개최': 299.37830538752746,
#  '상장': 1815.027364364988,
#  '주관': 62.32625159876809,
#  '사도': 28.10458223923418,
#  '참석': 10.283150912028574,
#  '가즈프롬': 1.4618996289220971,
#  '가스': 144.28173627982054,
#  '수요': 371.87304552777465,
#  '바닥': 159.15338588126755,
#  '개인화': 13.228906197024353,
#  '경험': 28.033831922987904,
#  '차별': 62.864351969845906,
#  '협상': 92.87116792502681,
#  '환경': 150.6034704084652,
#  '우호': 25.46611079025331,
#  '뉴스': 272.0772225508732,
#  '새벽': 92.47883780364891,
#  '불안': 92.01354773389944,
#  '여전': 69.95378946063913,
#  '앤트': 22.982678354724296,
#  '레터': 20.85650485300685,
#  '날개': 66.58293135175684,
#  '코스트코': 5.599764305906619,
#  '비밀': 10.362318874467164,
#  '병기': 0.3504453168659232,
#  '호조': 248.45698465883882,
#  '글로비스': 44.80102087342426,
#  '부진': 294.18053512847354,
#  '경쟁': 160.2583890028115,
#  '심화': 37.240660504637844,
#  '본격': 500.4401353370396,
#  '동시': 81.07545016870351,
#  '스위스': 18.261253340753306,
#  '협력': 256.2501560771887,
#  '공격': 77.58962338048008,
#  '행보': 42.890275981883214,
#  '체력': 23.6776322096555,
#  '과도': 57.35984268354527,
#  '상태': 27.13389903033392,
#  '베트남': 208.66156619660296,
#  '연초': 40.23051490274096,
#  '방위': 14.098280695765201,
#  '우량': 60.75846967192208,
#  '자격': 16.38149006367012,
#  '교체': 55.2262452855334,
#  '논의': 112.77052795009209,
#  '흑자': 507.2560554442224,
#  '진원': 60.62036181849204,
#  '생명과학': 129.7360904242258,
#  '연구': 149.74015427674743,
#  '손실': 571.8103270489374,
#  '자체': 40.62826739120772,
#  '악재': 156.98744601599702,
#  '불가피': 70.75626003979647,
#  '국면': 56.993008677190126,
#  '비중': 214.78189411068607,
#  '디스': 19.20695016987275,
#  '카운트': 22.68356898845612,
#  '해소': 184.48798965564654,
#  '지주회사': 15.356503683889306,
#  '컨트롤': 12.067479125406555,
#  '타워': 66.915566332221,
#  '역할': 38.35396202238623,
#  '수익': 651.5724560587294,
#  '못처': 0.6700890633731846,
#  '누가': 36.75562170162712,
#  '조선': 117.22834034414113,
#  '대한민국': 59.00821188150757,
#  '작작': 0.944272843971913,
#  '어쩜': 0.28445097071828235,
#  '탄원서': 3.4824340091612047,
#  '손가락': 5.107063106625858,
#  '꼬추에묶': 0.27418378059872844,
#  '재주': 10.32125011398895,
#  '부리고': 0.7360834095208255,
#  '왕서': 0.27418378059872844,
#  '방이': 3.0000607941113895,
#  '과열': 55.24635410699286,
#  '내일': 141.42868499998764,
#  '무궁': 0.27418378059872844,
#  '발전': 83.26843639883732,
#  '이백만': 0.27418378059872844,
#  '훨훨': 57.62778337655155,
#  '얼마': 22.08974146135013,
#  '갈기': 0.34017812674636927,
#  '조도': 0.8885456879438262,
#  '입성': 147.72604068996537,
#  '종합': 832.1198883259221,
#  '백만원': 4.736144203632215,
#  '도전': 73.611128128266,
#  '이주식': 2.4369740432526736,
#  '조만간': 14.199467817701825,
#  '액면': 37.24783888625175,
#  '분할': 353.39429891529295,
#  '쌈지': 0.27418378059872844,
#  '야금': 1.538161165189292,
#  '수고': 2.513174785408479,
#  '재천': -0.05572715602808692,
#  '부산': 99.63457127291176,
#  '중부': 10.249318989040686,
#  '경찰서': 3.0205343802391083,
#  '장님': 0.5586347513170107,
#  '이슈': 296.96786095919083,
#  '불확실': 201.01506758668256,
#  '크래프톤': 362.1610880275334,
#  '출격': 65.93046790421633,
#  '대기': 50.30832201237845,
#  '시기': 51.7955704475147,
#  '요인': 31.26422289927117,
#  '예상': 642.7441035557625,
#  '강재': 3.467714819499946,
#  '회복기': 2.558756339539789,
#  '기초': 14.291872528777807,
#  '풀필먼트': 4.148010278881295,
#  '운임': 61.031168673261966,
#  '레버리지': 81.99373820652669,
#  '트럼프': 19.268066957698977,
#  '노바': 51.33603243599655,
#  '메이트': 2.2712165603159464,
#  '금투협': 73.11824688488585,
#  '적극': 88.27331161892377,
#  '세제': 20.006058367023396,
#  '뒷받침': 7.523563563750813,
#  '재송': 12.986826383709035,
#  '개사': 106.81147512234786,
#  '상장폐지': 119.60898162848666,
#  '장투': 13.193713421235367,
#  '과세': 34.035255908135404,
#  '무쌍': 0.8225513417961854,
#  '장밋빛': 15.011751969378453,
#  '추천': 88.24478748950636,
#  '눈높이': 33.22766693244604,
#  '식품': 83.43095542622494,
#  '의류': 41.78951208049138,
#  '유통': 108.45794333521147,
#  '다산': 3.5292571661058822,
#  '슈퍼': 127.69351116390254,
#  '부양책': 51.014270248530906,
#  '이중': 5.829912105744351,
#  '항체': 50.26582926675273,
#  '달리기': 0.6700890633731846,
#  '후의': 0.6700890633731846,
#  '쾌감': 0.27418378059872844,
#  '사랑': 49.65164974174179,
#  '소액': 112.51321453540363,
#  '차지': 26.701376986622964,
#  '단연': 1.0865287263867487,
#  '큰손': 60.647076153977274,
#  '지주': 205.96397948900062,
#  '보사': 6.48385799430874,
#  '매물': 95.17706518765458,
#  '군침': 2.690623443612293,
#  '메가톤': 0.5483675611974569,
#  '사진': 30.84742080982423,
#  '라텍': 17.11312147364924,
#  '정광': 0.49264040516937,
#  '변경': 329.1272607810156,
#  '최저': 227.88908114376872,
#  '포토': 146.93229172755704,
#  '유래': 5.294778954949226,
#  '자동차': 176.2565417971194,
#  '생산': 384.71231525020113,
#  '중단': 264.97951472269534,
#  '역사': 43.75050330509518,
#  '직행': 30.167548570987634,
#  '서현': 10.763917759596692,
#  '회계법인': 66.94866872587218,
#  '컨설팅': 52.19277812721391,
#  '본부장': 24.00000233823503,
#  '성오': 1.49264040516937,
#  '바짝': 17.874130468839496,
#  '근접': 59.71034411805266,
#  '대림': 19.50463555099338,
#  '김상우': 0.27418378059872844,
#  '각자': 40.687415385118946,
#  '신기록': 41.42243957416052,
#  '수장': 19.403326840833987,
#  '위기': 181.72595183703228,
#  '특집': 3.4370348373640605,
#  '가치주': 59.33306521571377,
#  '라이브': 50.33182361290044,
#  '플렉스': 28.149738234585776,
#  '국세청': 3.1788726433513457,
#  '자영': 8.478103597842274,
#  '업자': 14.956267989795917,
#  '소상': 17.33999808264723,
#  '공인': 56.46196509950332,
#  '세무': 9.270096545725345,
#  '축소': 136.9939860594411,
#  '대한전선': 27.95645037213011,
#  '장호': 1.6143619073450977,
#  '사외이사': 74.91614153804414,
#  '중도': 11.180235834387481,
#  '퇴임': 8.890091261314133,
#  '영풍': 22.016507939477115,
#  '제련소': 1.7213642198595653,
#  '법적': 19.211158992968908,
#  '구제': 4.72742258688297,
#  '절차': 73.109401341679,
#  '검토': 228.66226299064857,
#  '선전': 75.04452701012211,
#  '수출': 291.8148491955283,
#  '휘파람': 1.2844509707182823,
#  '초읽기': 44.46901955465968,
#  '버킷': 15.504878727438918,
#  '스튜디오': 156.55577275161068,
#  '토지': 81.85172316232246,
#  '건물': 58.251715679970346,
#  '양수': 41.54291947352292,
#  '계룡': 8.057333523509788,
#  '제로': 74.53944017976333,
#  '단독주택': 0.6143619073450977,
#  '신축': 124.71207675022673,
#  '수주': 813.3961554739547,
#  '전이': 9.187837436546143,
#  '주역': 12.829790517521552,
#  '화학': 453.1516555873257,
#  '스토리': 67.09574137249709,
#  '브레인': 45.45514914432279,
#  '콘텐츠': 185.1579314102118,
#  '사이클': 67.14008132381507,
#  '고도화': 8.297687719355661,
#  '어가': 25.687899399775052,
#  '일주일': 33.102735033541975,
#  '전주': 28.193472583024885,
#  '서울시장': 6.275668559857651,
#  '당선': -40.20052236171108,
#  '유력': 34.61003383426117,
#  '닷컴버블': 13.087952711534264,
#  '이후': 235.5746773820175,
#  '모주': 322.3488389493831,
#  '청약': 835.5670313534258,
#  ...}

# %% [markdown]
# # vocab 정규화

# %%
robustScaler = RobustScaler()

# %%
# scale 할 리스트
vocab_v = [v for v in vocab.values()]
vocab_v_arr = np.array(vocab_v)

# %%
scaled_list = robustScaler.fit_transform(vocab_v_arr.reshape(-1,1))

# %%
scaled_list = np.squeeze(scaled_list, axis = 1)

# %%
for idx, v in tqdm(enumerate(vocab_v)) :
    vocab_v[idx] = list(scaled_list)[idx]

for i, k in tqdm(enumerate(vocab.keys())) :
    vocab[k] = vocab_v[i]
# Out:
# 35683it [00:38, 929.52it/s]
# 35683it [00:00, 1703743.52it/s]

# %%
vocab
# Out:
# {'비올': 2.739019999734513,
#  '일본': 53.585522484623176,
#  '최대': 740.2498486443225,
#  '병원체': -0.13535271802584783,
#  '인과': 1.0199223973594556,
#  '실펌': 0.0,
#  '엑스': 40.579758558019634,
#  '계약': 726.3436932416565,
#  '체결': 442.80853455904617,
#  '환율': 600.5368929971709,
#  '하락': 2055.378672144805,
#  '전환': 491.37963020145446,
#  '감소': 2729.2020860247585,
#  '코스피': 2664.5107945924447,
#  '오른': 383.2650707894781,
#  '출발': 801.2637964579145,
#  '달러': 697.6908349123573,
#  '증시': 1253.3819607049318,
#  '사상': 357.0154056766719,
#  '최고': 539.9656288290129,
#  '시작': 164.98205951151732,
#  '개장': 289.548041667412,
#  '안정': 88.90938451744708,
#  '시장': 625.537056328624,
#  '운영': 79.20600136321107,
#  '방점': 6.558693994769918,
#  '바이오': 717.0167354140684,
#  '아벨': 1.0075576868803284,
#  '매각': 268.9897528269889,
#  '자본': 61.203310722796154,
#  '이득': 0.3561364435181938,
#  '대웅제약': 23.38167905888755,
#  '코로나': 649.0133429678149,
#  '치료': 309.4014311990807,
#  '시험': 30.964602091681336,
#  '주가': 992.5304566990881,
#  '상승': 3875.347836548637,
#  '코스닥': 1387.5604375440023,
#  '포인트': 189.78188382920374,
#  '신년사': 35.03259761074361,
#  '영채': 16.318399374838734,
#  '투자': 1867.4364937880678,
#  '증권': 1819.8722170894723,
#  '대표': 267.42515869988006,
#  '데이터': 116.68668698594544,
#  '산이': 1.5916840627169693,
#  '경쟁력': 47.840139483907066,
#  '케이피': 13.430868952191203,
#  '에스': 271.31639034024283,
#  '올해': 439.92685867445323,
#  '사업': 681.3240871186296,
#  '시너지': 30.947348980447988,
#  '효과': 218.21329818147825,
#  '기관': 788.7847378011344,
#  '매도': 528.6582026730088,
#  '자산운용': 217.03798928014442,
#  '조직개편': 25.41463161254303,
#  '단행': 21.243276717534076,
#  '조직': 31.003563857692633,
#  '확대': 418.42888762047664,
#  '대체': 40.470676232618366,
#  '신설': 58.44935426361428,
#  '가치투자': 1.6822435624032928,
#  '대가': 10.111505171489357,
#  '방천': 2.562357698192333,
#  '주식': 1062.9877478325557,
#  '펀드': 453.8215577896355,
#  '가계': 22.802561129537974,
#  '연금': 144.50734558684704,
#  '자산': 410.4291080890774,
#  '변화': 49.20676434618623,
#  '개인': 332.088183979326,
#  '매수': 897.6214577131176,
#  '스팟': 59.28199839207947,
#  '외국인': 720.0287936616397,
#  '중립': 48.72210855712506,
#  '윤관석': 0.0651571300528143,
#  '정무': 0.1281164997665455,
#  '위원장': 21.25133594163462,
#  '자본시장': 29.264986526597724,
#  '질서': 3.3079709789440934,
#  '유지': 148.33833735505723,
#  '삼성': 1118.4763276165427,
#  '전자': 622.588977839508,
#  '반도체': 425.3640184847532,
#  '업황': 52.156371109840045,
#  '회복': 450.14537653673057,
#  '기대': 538.5285428930082,
#  '목표': 1119.2501308673927,
#  '하이': 147.01934756298454,
#  '성수': 0.7399041827280738,
#  '금융': 542.3759209037486,
#  '사모펀드': 71.07686793757334,
#  '사태': 85.94850499776899,
#  '신뢰': 19.96724136637432,
#  '만전': -0.04485324120592774,
#  '손병두': 12.258430759872148,
#  '거래소': 350.83184189978294,
#  '이사장': 24.366855142314755,
#  '공매도': 307.9504130323526,
#  '적법': 0.5689509792095794,
#  '사전': 31.418713167458552,
#  '사후': 0.5393031460639135,
#  '관리': 145.37617080660937,
#  '강화': 219.4584136764387,
#  '증가': 986.655611301246,
#  '속보': 252.88310719910478,
#  '새해': 92.74517234354094,
#  '거래': 820.4397471422114,
#  '최석': 3.5562047772430216,
#  '대표이사': 71.29572169705382,
#  '주주': 397.1203325728662,
#  '가치': 209.29108146776485,
#  '역량': 21.744962840651326,
#  '집중': 77.77046794172834,
#  '위지트': 0.6340780978291919,
#  '신고': 764.5621326125108,
#  '경신': 701.2208535598531,
#  '전일': 132.80188125514766,
#  '대량': 124.1677004258732,
#  '베스트': 97.89636821258172,
#  '넘버원': 2.178038210325895,
#  '중형': 6.075846971702094,
#  '증권사': 291.4357146443703,
#  '달성': 171.97862608813006,
#  '에프': 154.95717772482135,
#  '최근': 48.24069631142154,
#  '프로그램': 76.66883595461981,
#  '우위': 43.42693514586989,
#  '동양': 12.912079775006578,
#  '엔피': 10.463186071462987,
#  '단기간': 21.10874585106362,
#  '골든': 25.890451343098174,
#  '크로스': 21.390994146039045,
#  '형성': 28.58452806732713,
#  '킨스': -0.9344613784597551,
#  '단기': 219.32655959895234,
#  '중기': 145.74819945829296,
#  '이평': 150.24255932885137,
#  '배열': 144.2448471234902,
#  '상승세': 331.8693544598486,
#  '세진': 3.2283114009394733,
#  '티에스': 12.229125749636536,
#  '미니': 13.480087702642104,
#  '핵심': 81.89287072632807,
#  '공급': 507.9143208210935,
#  '업체': 159.3422163327987,
#  '델타': 96.2853210040208,
#  '테크': 281.543992432501,
#  '실리콘': 28.755540139426095,
#  '웍스': 13.207304551984125,
#  '종가': 76.65507917535443,
#  '기준': 111.64529371670211,
#  '현우': 1.904462065259861,
#  '산업': 262.14191945046633,
#  '이노베이션': 91.58626469045198,
#  '연속': 340.9151444040602,
#  '이엔드디': 2.1751975127447594,
#  '경창': 0.11291109170628261,
#  '인트론': 2.128146511199748,
#  '메기': 1.1878536804117106,
#  '아이': 202.10182532999494,
#  '동서': 7.345588001890701,
#  '하이닉스': 175.5758588031312,
#  '삼진': 6.620980415808397,
#  '앤디': 43.15889033880016,
#  '서울': 69.54635063857901,
#  '잠시': 4.776637022681135,
#  '대위': 24.678720104716785,
#  '업종': 188.99587169650505,
#  '대비': 452.8649964534773,
#  '현대': 325.96098051970296,
#  '모비스': 17.640140984478837,
#  '공영': 9.578556369262975,
#  '피지': 4.6811891222406015,
#  '인텍': 6.004918412187405,
#  '플러스': 110.69260500971565,
#  '규모': 935.4325438211143,
#  '관련': 334.30062221781697,
#  '장비': 157.52985358460634,
#  '납품': 33.7403572399407,
#  '소식': 322.1266494023996,
#  '강세': 957.960376828271,
#  '하나': 313.5514352679411,
#  '기술': 379.6623275136288,
#  '각각': 15.638002092720313,
#  '특징': 1974.736675645784,
#  '중증': 5.774087782287821,
#  '승인': 236.4877377323904,
#  '급등': 676.2929185138192,
#  '전시': 59.34923323673866,
#  '한화': 210.96372945154457,
#  '비대': 51.143043147783644,
#  '국내': 460.148355748626,
#  '해외': 322.68358426547496,
#  '이벤트': 161.7049933830554,
#  '법무': 12.545043409806688,
#  '법인': 92.46112105400071,
#  '태평양': 11.08208877266512,
#  '서동우': -0.13535271802584783,
#  '신임': 47.03150681057518,
#  '업무': 101.54325138095798,
#  '집행': 6.521076971823293,
#  '변호사': 7.989130089751485,
#  '취임': 30.750814492982734,
#  '전망': 632.596274080621,
#  '상향': 177.4636056543839,
#  '조정': 202.28606782699143,
#  '간다': 103.46055718534251,
#  '지수선물': 44.19279344688806,
#  '보합': 175.7654237123784,
#  '미국': 382.75211652748186,
#  '중국': 456.25645000530153,
#  '통신사': 7.100104866873306,
#  '석유': 50.699367970759425,
#  '회사': 202.66090601053767,
#  '출하': 6.418332830257056,
#  '고비': 3.4237827910979166,
#  '물량': 57.473896113115096,
#  '해제': 58.99435265627147,
#  '평가': 276.46173975123884,
#  '분석': 107.22213135427123,
#  '박학주': 0.6767635901292393,
#  '선임': 109.86471653912629,
#  '그린': 93.98111126565672,
#  '스마트': 74.8922064347969,
#  '수혜': 207.40943617173988,
#  '와우': 17.500421602922167,
#  '공개방송': 12.761401603187672,
#  '뉴욕증시': 378.40623475982846,
#  '마감': 1647.1959498421586,
#  '영향': 173.33749299492706,
#  '관심': 61.53758960865623,
#  '종목': 731.1951014415871,
#  '공시': 537.3513790542431,
#  '두산': 67.32591089028267,
#  '퓨얼': 22.437274661750855,
#  '연료': 22.667732457307224,
#  '전지': 33.43127179796757,
#  '시스템': 214.89864388721747,
#  '글로벌': 547.2518773017492,
#  '세계': 174.2224943771841,
#  '경제': 131.48120505138553,
#  '지옥': 6.330944153917086,
#  '상춘': 27.603658624564375,
#  '금세': 14.768607810013773,
#  '경기': 146.79962693479854,
#  '반등': 377.13073730589707,
#  '진정': 24.992112187354376,
#  '건설': 287.77823051435524,
#  '밸류': 65.3033769210922,
#  '매력': 79.49621769370144,
#  '오늘': 257.27264290491985,
#  '주식시장': 64.84644130773621,
#  '오전': 66.40765453146611,
#  '리츠': 237.88877070283695,
#  '유럽': 187.74297977748705,
#  '주요': 65.17397570112733,
#  '개국': 12.01282757912196,
#  '서비스': 297.5234923150537,
#  '개시': 91.88261374188842,
#  '길라잡이': 9.505550095142004,
#  '자율': 52.48432566329569,
#  '주행': 40.19935671647205,
#  '주목': 389.9528739698892,
#  '바이두': 5.568539476288942,
#  '김원규': 2.6362458467350725,
#  '사장': 79.5433575752602,
#  '현재': 89.76079156309312,
#  '사이언티': 4.321300095286299,
#  '메디프론': 5.064715615698976,
#  '확장': 88.61351564894166,
#  '마켓': 520.1298144543449,
#  '브리핑': 93.49946123705874,
#  '차입': 17.93838537335086,
#  '포스코에너지': 0.27070543605169567,
#  '정책': 96.25087595870578,
#  '지원': 143.1979248248229,
#  '실적': 1291.3814274248898,
#  '신호': 49.80184951228518,
#  '전기차': 208.3132466426136,
#  '확보': 117.65432484952345,
#  '미래에셋': 279.42978046059403,
#  '대우': 18.2650840637558,
#  '회장': 167.58850631365436,
#  '테라': 32.15676125847162,
#  '퓨틱스': 15.546889690091556,
#  '양도': 21.476514033519273,
#  '결정': 554.0903482654097,
#  '워드': 16.809917393530103,
#  '계속': 64.74009463989951,
#  '시대': 174.16741185439946,
#  '외환': 105.1076654394676,
#  '조지아주': 3.328184833491374,
#  '상원': 9.450409858063226,
#  '선거': 13.939731270701385,
#  '촉각': 12.668092594505692,
#  '예고': 78.09649137488674,
#  '검증': 11.551689210832038,
#  '시간': 66.09051217396429,
#  '필요': 81.95140456393013,
#  '의견': 118.08579922466485,
#  '보유': 161.6006597898151,
#  '하향': 132.50123133447477,
#  '유진': 127.72599792343907,
#  '호텔': 103.24829324402182,
#  '신라': 82.21206194128929,
#  '닛케이지수': 59.41380745241577,
#  '에이': 118.73095731277515,
#  '피티': 2.6217734102164676,
#  '차세대': 38.12928117423186,
#  '공정': 29.403088753619272,
#  '진입': 78.50664493531042,
#  '운용': 288.8882068341827,
#  '이현승': 1.7769885027353685,
#  '단독': 161.41911024180578,
#  '체제': 55.62983552003177,
#  '역대': 251.66873380031691,
#  '사주': 182.39213169478612,
#  '성과급': 10.804027072621313,
#  '급증': 117.83091327676884,
#  '국채선물': 43.16715964293306,
#  '연내': 46.30166684654272,
#  '대화면': 0.0,
#  '제품': 87.74714213241558,
#  '항암제': 28.911689626374876,
#  '속도': 74.33370636005678,
#  '최현': 19.01317790489027,
#  '수석': 10.91406745531326,
#  '부회장': 34.605967773492104,
#  '비즈니스': 42.93333825828643,
#  '디지털': 135.3664551822528,
#  '가속': 57.634891292240006,
#  '보호': 42.10241517008666,
#  '예수': 13.928802491872306,
#  '티어': 19.037295554325482,
#  '도약': 77.16925005468342,
#  '큐렉소': 1.6945182385828146,
#  '의료': 52.24341811755568,
#  '의료로봇': 1.1125596116520537,
#  '금융투자': 179.87649602665832,
#  '협회': 30.515006582315113,
#  '이해': 5.842205655654576,
#  '과정': 29.31933261498267,
#  '개설': 62.23866130539321,
#  '기업가': 4.227959920885245,
#  '치평': 0.6615881935021781,
#  '실무': 10.937152018874878,
#  '신축년': 3.7393114569223376,
#  '진검': 0.2685376871458145,
#  '승부': 19.333073234245546,
#  '선택': 30.997120633841355,
#  '고객': 150.4991201455783,
#  '기업': 806.454194184434,
#  '크기': 9.433126735396687,
#  '활용': 50.04346001813375,
#  '이진우': 1.0503032020467806,
#  '주간': 65.89259716057077,
#  '호재': 74.6261804737529,
#  '재는': 3.8696557284611686,
#  '한미': 66.85726504654887,
#  '특별': 92.62810697690784,
#  '지급': 49.74841530975525,
#  '유안': 57.79745283732109,
#  '접점': 1.4585291050302045,
#  '드론': 2.2171211763558403,
#  '신규': 233.23432638472258,
#  '특허': 98.3964845068856,
#  '서브': 5.317434968975675,
#  '스트레이트': 0.483549983176283,
#  '검사': 78.7975953916282,
#  '장마': 20.61991847278733,
#  '친환경': 95.77376804509532,
#  '아스콘': 1.8921273662139366,
#  '설비': 50.59790854939139,
#  '순풍': 3.122666538925695,
#  '매출': 699.9192057590185,
#  '성과': 64.59095513117568,
#  '엠디': 2.2555300394246354,
#  '중국군': 0.19544137872524117,
#  '통제': 6.321330106719487,
#  '자금': 163.53785394012593,
#  '조치': 25.48717501802118,
#  '유입': 33.7182757508195,
#  '정상화': 55.04920893902059,
#  '무엇': 5.3832350362705395,
#  '중요': 11.370751434344504,
#  '포비': 1.2204022340049159,
#  '스티': 6.025955272575942,
#  '적격성': 0.41115663486416665,
#  '실질': 14.30679764733447,
#  '심사': 74.82748447052545,
#  '대상': 120.42936434052994,
#  '정지': 69.58685106768543,
#  '안랩': 38.014498985094,
#  '미래': 94.53031356753324,
#  '성장': 589.8053816271614,
#  '제도': 38.10414890749709,
#  '개선': 339.5889345537305,
#  '도입': 108.15405099519562,
#  '중점': 3.8725564489087065,
#  '추진': 244.32538511305688,
#  '나인': 25.123981270557035,
#  '대감': 420.2506958901232,
#  '한국': 589.5914543598764,
#  '정보': 72.18256762816674,
#  '인증': 69.28093644905802,
#  '전자서명': 0.1382534384733874,
#  '공동': 109.3898687172938,
#  '진출': 168.7625293405038,
#  '신청': 98.02346894076304,
#  '상한': 145.35911276969068,
#  '현대차': 242.34754624790534,
#  '급락': 332.56134885232655,
#  '의무': 56.654886409610896,
#  '모두': 59.737096382294645,
#  '고통': 2.117949549626503,
#  '텍티앤': 1.669145880382507,
#  '티머니': 3.337678834956162,
#  '단말기': 3.27545243678409,
#  '통합': 61.500613214380046,
#  '보수': 40.47641649636135,
#  '동학': 145.12254072176324,
#  '개미': 631.332451074205,
#  '그룹': 447.693941095652,
#  '공략': 61.8528470172961,
#  '독보': 4.59206555420439,
#  '입지': 18.038258805902768,
#  '패스': 21.76315784917288,
#  '아크': 8.704333708668617,
#  '인포': 5.837107174867951,
#  '뱅크': 164.47666351354275,
#  '에코': 133.51891095434578,
#  '수도권매립지': 0.49145915011083996,
#  '공사': 206.28069578044796,
#  '러브콜': 21.204313797236946,
#  '선두': 18.337117274869495,
#  '선진': 14.702045914029942,
#  '국방': 0.49441989342478443,
#  '과학': 15.988980032585474,
#  '연구소': 32.265949778175006,
#  '화두': 2.922216713713435,
#  '리스크': 115.36791881676376,
#  '해성': 30.23035044696822,
#  '안철수': 32.21118237543945,
#  '지지율': 12.517533314133706,
#  '터치': 52.584406867308246,
#  '등락': 61.714835978860144,
#  '액티브': 53.77736018279247,
#  '김유상': 0.9474690261809351,
#  '공세': 5.295726314197768,
#  '경보': 14.083053178528198,
#  '제약': 179.1350543351222,
#  '최초': 159.88766374266777,
#  '난치': -0.09483497463168186,
#  '혈액암': 2.2128145356913853,
#  '치료법': 12.509564124332748,
#  '원료': 19.05662638016519,
#  '부각': 240.44533850299246,
#  '접근': 19.99243365597544,
#  '케이': 209.54961957622584,
#  '포스코': 57.97289390438889,
#  '케미칼': 101.62367394193777,
#  '티움': 3.3304126052636582,
#  '거듭': 12.137370409765714,
#  '크리스탈': 13.15222433777175,
#  '지노': 34.8959301610863,
#  '믹스': 47.99249252455578,
#  '러시아': 97.06417310132932,
#  '아셀': 1.7292345410819001,
#  '렉스': 29.901231219047,
#  '품목': 20.028854838737534,
#  '허가': 114.52634859549316,
#  '아스': 27.301106440742068,
#  '결합': 26.391464517540197,
#  '백신': 272.87522688931904,
#  '접종': 43.84462503888488,
#  '아이디': 11.406842491341408,
#  '트론': 24.2449729406529,
#  '정일': 8.906278334111501,
#  '혁신': 91.68796651185704,
#  '일상': 15.29261551371782,
#  '확산': 105.69940202219315,
#  '악화': 33.16786260304156,
#  '훌쩍': 11.364425947654281,
#  '중반': 19.42659232295994,
#  '구조조정': 15.669055846082887,
#  '폭풍': 37.74765232678059,
#  '희비': 29.0198623744929,
#  '교차': 6.825123955876253,
#  '싸이': 3.739461514088339,
#  '토젠': 0.19834209917278078,
#  '도시바': 5.478070010902224,
#  '임원': 21.411209154872115,
#  '승진': 9.792896870904062,
#  '대상자': 13.878999672759948,
#  '스타트업': 38.40285731929787,
#  '연수': 2.8440519359394414,
#  '잡기': 5.067003410337662,
#  '박차': 31.67333132102816,
#  '사후관리': -0.46104833399031414,
#  '푸드': 50.63860520709899,
#  '나무': 46.286312535602384,
#  '충성': 0.5088623185101858,
#  '지속': 302.22838008095033,
#  '적정': 29.3294995651227,
#  '서희': 2.5110600788492685,
#  '퓨쳐켐': 4.313330905485336,
#  '바이든': 72.69144148953633,
#  '정부': 105.63879162426961,
#  '출범': 57.64155844755457,
#  '재생': 16.92276961665585,
#  '에너지': 192.53567984264765,
#  '대원': 14.711359846895514,
#  '전선': 18.878588169839272,
#  '성도': 0.5719117225235231,
#  '관계자': 74.87432308346688,
#  '변동': 112.83607697470897,
#  '네스': 2.461078345423515,
#  '미원': 6.668764388895066,
#  '홀딩스': 209.87429826631873,
#  '엑시콘': 4.165643488413564,
#  '솔루션': 149.0394760003768,
#  '녹십자': 40.925951982861015,
#  '랩셀': 8.037496977213806,
#  '심텍': 5.356547946438811,
#  '넥스': 44.1360083524126,
#  '임상시험': 21.69070447799437,
#  '동일': 14.114898772012953,
#  '유동성': 44.297361360164025,
#  '이건': 4.843170061517654,
#  '전기': 117.36922200553558,
#  '처음': 15.168162717373647,
#  '콤보': 1.0423640236790206,
#  '기우': 1.9499882551410448,
#  '엘오티베큠': 3.1052333590931465,
#  '유니': 25.770826924641817,
#  '팬오션': 20.394455272287328,
#  '넷게임즈': 2.065187141486018,
#  '탄력': 26.625808793696166,
#  '월덱스': -0.19254065827770164,
#  '프로비': 73.5905297768241,
#  '동원': 30.349002956703178,
#  '개발': 366.3630898617465,
#  '폴리': 8.087598756372365,
#  '말레이시아': 6.8288465278791675,
#  '공장': 124.50716782681963,
#  '약세': 264.8327387799083,
#  '기부': 28.825706870251715,
#  '전달': 39.28388334094195,
#  '사자': 121.74479431490998,
#  '듀오': 0.8548618233215388,
#  '오토': 26.529898024612763,
#  '에버': 9.11258962308524,
#  '리서치': 48.51039982731865,
#  '알음': 16.35879707250008,
#  '플랫폼': 249.3774232067999,
#  '익일': -0.13535271802584783,
#  '배송': 52.43018734637154,
#  '다이어트': 0.518999257217028,
#  '혜주': 82.99007718132552,
#  '동화': 3.707495874870792,
#  '티스': 18.17440451833668,
#  '투명': 8.854831811888323,
#  '교정': 0.8548918347547401,
#  '상반기': 177.84255540427864,
#  '출시': 372.26367352640597,
#  '정문화': -0.13535271802584783,
#  '개편': 47.95677430190202,
#  '단자': 1.7842847438610747,
#  '방전': 4.112851068839875,
#  '코러스': 2.438576696237547,
#  '호중': -0.15779434434541315,
#  '돌파': 561.1687848775101,
#  '원년': 7.664047399595871,
#  '전략': 202.0127283105332,
#  '선포': 11.940344196510239,
#  '첫날': 238.3836904020517,
#  '질주': 31.395149575251565,
#  '배터리': 246.95905805653734,
#  '이노': 134.18480809708527,
#  '인구': 10.751204641614425,
#  '인팩': 0.9070113056531726,
#  '신약': 72.49946989420339,
#  '완료': 104.24891713554663,
#  '상사': 15.684081185543944,
#  '네스엠': 0.0,
#  '영업': 1311.544791198696,
#  '조회': 40.69213059821442,
#  '요구': 45.5781662206313,
#  '네트웍': 25.27747012852388,
#  '오늘이': 2.9272251602004538,
#  '무덤': 4.375677349390216,
#  '트릭': 13.919547427587318,
#  '뉴딜': 31.855003223343274,
#  '수소': 56.34522036183381,
#  '인프라': 79.73440343330773,
#  '가능성': 166.49308092178904,
#  '왜팔': -0.13535271802584783,
#  '뼈속': -0.13535271802584783,
#  '발라': 0.19544137872524117,
#  '눌림': 0.5262354754763302,
#  '수량': 1.446224417417482,
#  '지금': 141.448116291994,
#  '아침': 7.744319903409342,
#  '호가': 11.450469880929637,
#  '예수금': 0.7115699269279311,
#  '추가': 205.01586046530295,
#  '제일': 5.844373404560455,
#  '월달': 1.8494418739138894,
#  '어어': 2.034746313932288,
#  '백만': 35.010920121684705,
#  '달뒤': -0.13535271802584783,
#  '가격': 308.33469673735596,
#  '손까락묵': -0.13535271802584783,
#  '저번': 3.0198623744930515,
#  '평단': 15.710335418166036,
#  '어제': 31.038310171624943,
#  '수익률': 219.34918591101558,
#  '약주': 4.6811290993742,
#  '기회': 106.35249928867,
#  '기억': 3.6641074224622883,
#  '주님': 4.661528170635772,
#  '고체': 24.722901551533337,
#  '테마': 73.34150298411696,
#  '주민': 5.373128108996899,
#  '가면': 2.4112166577305736,
#  '이제': 55.975612247665595,
#  '아무': 1.1103918627461729,
#  '구매': 37.86566189927344,
#  '금사면': -0.07019558797303355,
#  '꼬리': 1.9601852167142917,
#  '분기': 205.99739015959446,
#  '이내': 3.0575694317392847,
#  '만원': 68.58908634231568,
#  '도주': 13.159550590330657,
#  '상투': 0.37857806983775916,
#  '이번': 106.58041534669205,
#  '금요일': 5.132100517524075,
#  '야호': -0.10277415299944069,
#  '팔면': 0.9026457964082092,
#  '어디': 48.005411292263126,
#  '안착': 42.314105431319035,
#  '서민': 6.290216330490509,
#  '살수': 0.23815688245849037,
#  '주지': 0.982275362979627,
#  '대세': 28.161276824882634,
#  '불변': -0.26056849734485377,
#  '탈출': 18.74812500685351,
#  '중이': 5.012536121934139,
#  '두리': 0.06008866069939335,
#  '가지': 42.85749128658419,
#  '역사상': 0.568980990642781,
#  '일대': 1.153077355046221,
#  '여러분': 2.180235970664978,
#  '축하': 6.441387382385473,
#  '물반': -0.13535271802584783,
#  '기반': 70.07585851456064,
#  '보고': 264.82369841279484,
#  '반영': 56.1956341444689,
#  '난혼': -0.13535271802584783,
#  '시가': 4.528463247248613,
#  '시긴': 0.0,
#  '최고점': 12.078926606462957,
#  '외로': -0.16286281369883404,
#  '동안': 41.79479336262511,
#  '가즈': 8.531213910530136,
#  '기네': 0.5588140405027374,
#  '장주': 110.01678447116024,
#  '안티': 8.806987815935255,
#  '사망': 2.877303449641104,
#  '욀케': -0.13535271802584783,
#  '아씨': -0.3807458187436405,
#  '바로': 10.81266921109752,
#  '갈라': 2.3155586772576235,
#  '왜케올': -0.13535271802584783,
#  '일단': 7.194268047115618,
#  '현실': 30.521239726134027,
#  '정도': 11.297804028804041,
#  '장전': 4.3235278670585835,
#  '대주': 16.289513370382053,
#  '안해': 19.37089918293873,
#  '악덕': -0.13535271802584783,
#  '흑우': 2.3510379627315707,
#  '한번': 18.45073132668422,
#  '대박': 57.162120030726776,
#  '팔고': 32.279286397375536,
#  '나와라': 0.5588140405027374,
#  '합격': 4.849090393859656,
#  '통보': 14.920900827796123,
#  '당시': 0.4661768262101387,
#  '주변': 2.7643323350684175,
#  '반응': 11.162481322211393,
#  '이재용': 46.60604049350313,
#  '역시': 18.127233471058826,
#  '방금': 2.1100103712587424,
#  '잘못': 2.431340477978244,
#  '거지': 1.2435468204329396,
#  '올린다': 5.879762655734801,
#  '사중': 1.0075876983135306,
#  '입질': 0.5313039448297512,
#  '정초': 0.4509714181498758,
#  '도마': 3.456271321824718,
#  '어우': 0.09266722572580054,
#  '대장': 24.689680049264865,
#  '래서': 0.06008866069939335,
#  '코인': 1.7372037308828618,
#  '그냥': 9.530832419042707,
#  '사마': 2.3003832806305624,
#  '쭉쭉': 6.505871563763032,
#  '설거지': 1.7842847438610743,
#  '라면': 11.132773466199321,
#  '대금': 73.95738607342467,
#  '리차': 3.134971226538417,
#  '개월': 230.36587630787744,
#  '은행업': 2.6963645188676675,
#  '이자': 35.336032823273605,
#  '이익': 521.6765621672722,
#  '케이프': 16.983411180297697,
#  '초점': 7.3462309391327585,
#  '금투': 220.9481465919975,
#  '나스': 5.691557495268862,
#  '미디어': 64.31102579655793,
#  '빅데이터': 51.20969392378118,
#  '모멘텀': 84.61021439128946,
#  '클릭': 329.7164485162553,
#  '작년': 230.96321002289434,
#  '적자': 135.4173361043884,
#  '철강': 58.93899079630132,
#  '여력': 27.97603240773062,
#  '충분': 8.015205408060242,
#  '국민연금': 91.5777472148514,
#  '투자자': 165.19444234428514,
#  '온라인': 103.60033543547969,
#  '배너': 0.5313039448297512,
#  '광고': 56.29404047965161,
#  '가세': 10.370488834303984,
#  '신한': 90.71880152804266,
#  '환자': 38.48972310412856,
#  '계획': 136.74062907426855,
#  '서학': 149.87443562634112,
#  '지난해': 329.0128143048472,
#  '상위': 116.95420774721967,
#  '테슬라': 315.3179417004847,
#  '지수': 247.25286652472568,
#  '린다': 16.793980168214052,
#  '제일제당': 33.692229289658215,
#  '장기': 139.98643252362035,
#  '성장동력': 16.941637573852624,
#  '굿모닝': 39.23955299124525,
#  '위험': 78.73170529003362,
#  '선호': 34.57676895755858,
#  '심리': 71.5829945985186,
#  '연말': 52.61912547837904,
#  '풍산': 7.5322983621260065,
#  '기존': 17.743676966167254,
#  '정치': 42.08761145351719,
#  '상회': 76.37166620591331,
#  '통운': 17.59935313818588,
#  '택배': 16.220453599727122,
#  '단가': 11.451725743980536,
#  '인상': 304.70623250896523,
#  '여부': 32.45421496150731,
#  '일정': 15.079981046625615,
#  '대형주': 44.13191294606639,
#  '솔젠트': 1.9145689925335014,
#  '신년': 4.756393156700653,
#  '간담': 1.6005662926588051,
#  '개최': 147.51946385728868,
#  '상장': 895.7300956384352,
#  '주관': 30.497079368120737,
#  '사도': 13.603315801654432,
#  '참석': 4.805643072870639,
#  '가즈프롬': 0.4509714181498758,
#  '가스': 70.95497073019509,
#  '수요': 183.30699329879315,
#  '바닥': 78.29646332573925,
#  '개인화': 6.2598355258031875,
#  '경험': 13.56838941912294,
#  '차별': 30.76271633481897,
#  '협상': 45.57578839169304,
#  '환경': 74.07573846882765,
#  '우호': 12.300816137840204,
#  '뉴스': 134.04209565220853,
#  '새벽': 45.38211191609718,
#  '불안': 45.15241825780163,
#  '여전': 34.26246614335181,
#  '앤트': 11.074852554405823,
#  '레터': 10.025252312467494,
#  '날개': 32.59841874375591,
#  '코스트코': 2.4936569104499235,
#  '비밀': 4.844724884614688,
#  '병기': -0.09770568364601974,
#  '호조': 122.38180199033461,
#  '글로비스': 21.845628113325436,
#  '부진': 144.95354864997563,
#  '경쟁': 78.84195575275815,
#  '심화': 18.113403971782294,
#  '본격': 246.77502563957265,
#  '동시': 39.752750807567175,
#  '스위스': 8.744088469087918,
#  '협력': 126.22895491532385,
#  '공격': 38.03194832492922,
#  '행보': 20.902375693509313,
#  '체력': 11.417921327336424,
#  '과도': 28.045377287000886,
#  '상태': 13.124131327723113,
#  '베트남': 102.73651866220543,
#  '연초': 19.589366256644993,
#  '방위': 6.689008254875545,
#  '우량': 29.723132985854708,
#  '자격': 7.81613033734581,
#  '교체': 26.992112187354355,
#  '논의': 55.39924498159746,
#  '흑자': 250.13975170155803,
#  '진원': 29.654955089621566,
#  '생명과학': 63.77441213662346,
#  '연구': 73.64955649450228,
#  '손실': 282.0074139782869,
#  '자체': 19.785719521225264,
#  '악재': 77.22723214362948,
#  '불가피': 34.65861129018558,
#  '국면': 27.864287144775638,
#  '비중': 105.75786083121211,
#  '디스': 9.210938243973313,
#  '카운트': 10.92719514876724,
#  '해소': 90.80306555247215,
#  '지주회사': 7.310138727849961,
#  '컨트롤': 5.686489025915444,
#  '타워': 32.76262630051942,
#  '역할': 18.662992959433172,
#  '수익': 321.38254015616894,
#  '못처': 0.06008866069939335,
#  '누가': 17.873961214839692,
#  '조선': 57.59987487540909,
#  '대한민국': 28.859106132547772,
#  '작작': 0.19544137872524117,
#  '어쩜': -0.13028424867242688,
#  '탄원서': 1.4484221777565638,
#  '손가락': 2.2504315586380113,
#  '꼬추에묶': -0.13535271802584783,
#  '재주': 4.824451007201006,
#  '부리고': 0.09266722572580054,
#  '왕서': -0.13535271802584783,
#  '방이': 1.2102953067312756,
#  '과열': 27.00203904602882,
#  '내일': 69.54654225003758,
#  '무궁': -0.13535271802584783,
#  '발전': 40.83533361459426,
#  '이백만': -0.13535271802584783,
#  '훨훨': 28.17764806169418,
#  '얼마': 10.63404808639598,
#  '갈기': -0.10277415299944069,
#  '조도': 0.167931283052255,
#  '입성': 72.65527540395622,
#  '종합': 410.51102775885806,
#  '백만원': 2.067324878958695,
#  '도전': 36.067936650481535,
#  '이주식': 0.9323236409870764,
#  '조만간': 6.738959976868099,
#  '액면': 18.116947629471845,
#  '분할': 174.18483233708844,
#  '쌈지': -0.13535271802584783,
#  '야금': 0.48861845252970393,
#  '수고': 0.9699406639337025,
#  '재천': -0.29821553172468185,
#  '부산': 48.91458919253659,
#  '중부': 4.788941710293859,
#  '경찰서': 1.2204022340049159,
#  '장님': 0.005068469353420902,
#  '이슈': 146.32953130798478,
#  '불확실': 98.96177178267249,
#  '크래프톤': 178.5126183648031,
#  '출격': 32.27632565406156,
#  '대기': 24.564345378498906,
#  '시기': 25.29853584605975,
#  '요인': 15.163094248020249,
#  '예상': 317.02436293519145,
#  '강재': 1.4411559480640606,
#  '회복기': 0.992442313119671,
#  '기초': 6.7845762010488855,
#  '풀필먼트': 1.7769885027353685,
#  '운임': 29.857752732338938,
#  '레버리지': 40.20607004322209,
#  '트럼프': 9.24110896862823,
#  '노바': 25.0716817310594,
#  '메이트': 0.8504963140765759,
#  '금투협': 35.82462241865577,
#  '적극': 43.30602485292951,
#  '세제': 9.605423527693908,
#  '뒷받침': 3.443353708403144,
#  '재송': 6.140331153079654,
#  '개사': 52.45751737344537,
#  '상장폐지': 58.77509489672864,
#  '장투': 6.242462368837041,
#  '과세': 16.531033841930917,
#  '무쌍': 0.13535271802584786,
#  '장밋빛': 7.13994966159222,
#  '추천': 43.291943719328046,
#  '눈높이': 16.13236196327869,
#  '식품': 40.915562255543755,
#  '의류': 20.358975986813416,
#  '유통': 53.27030778456163,
#  '다산': 1.4715367527513852,
#  '슈퍼': 62.7660787696232,
#  '부양책': 24.9128416036955,
#  '이중': 2.607270962264666,
#  '항체': 24.54336854097678,
#  '달리기': 0.06008866069939335,
#  '후의': 0.06008866069939335,
#  '쾌감': -0.13535271802584783,
#  '사랑': 24.240174574198278,
#  '소액': 55.272220436285046,
#  '차지': 12.910613831923275,
#  '단연': 0.2656669781314765,
#  '큰손': 29.66814280594193,
#  '지주': 101.40483634245967,
#  '보사': 2.930095869214792,
#  '매물': 46.714110510176795,
#  '군침': 1.0575394203060817,
#  '메가톤': 0.0,
#  '사진': 14.9573370162748,
#  '라텍': 8.177305238784223,
#  '정광': -0.02751009567298617,
#  '변경': 162.2052412659506,
#  '최저': 112.22831428665299,
#  '포토': 72.2634357435009,
#  '유래': 2.3430987843638116,
#  '자동차': 86.739554434102,
#  '생산': 189.64518752239943,
#  '중단': 130.538263134474,
#  '역사': 21.32703285617074,
#  '직행': 14.621713387350052,
#  '서현': 5.042976949487866,
#  '회계법인': 32.778967525897755,
#  '컨설팅': 25.494620162027047,
#  '본부장': 11.57706156903234,
#  '성오': 0.4661468147769369,
#  '바짝': 8.552982588174446,
#  '근접': 29.205718563167917,
#  '대림': 9.35789268950343,
#  '김상우': -0.13535271802584783,
#  '각자': 19.81491833715879,
#  '신기록': 20.177768107427013,
#  '수장': 9.307880944644477,
#  '위기': 89.43956649638918,
#  '특집': 1.4260105628702002,
#  '가치주': 29.019472225861364,
#  '라이브': 24.575947106003223,
#  '플렉스': 13.625607370807991,
#  '국세청': 1.2985670117789099,
#  '자영': 3.9145689925334985,
#  '업자': 7.112559611652038,
#  '소상': 8.289304444635528,
#  '공인': 27.602133812900494,
#  '세무': 4.305541784283582,
#  '축소': 67.35732247227183,
#  '대한전선': 13.530189481800658,
#  '장호': 0.5262354754763302,
#  '사외이사': 36.71216553844833,
#  '중도': 5.248495244053546,
#  '퇴임': 4.117949549626499,
#  '영풍': 10.597895852246781,
#  '제련소': 0.5790579064832194,
#  '법적': 9.213015958579591,
#  '구제': 2.063019392580134,
#  '절차': 35.820255755125025,
#  '검토': 112.61000084839966,
#  '선전': 36.77554391394099,
#  '수출': 143.78571144122304,
#  '휘파람': 0.36337266177749616,
#  '초읽기': 21.681733368038817,
#  '버킷': 7.3833850934365355,
#  '스튜디오': 77.01413365360868,
#  '토지': 40.13596333526282,
#  '건물': 28.485656554929804,
#  '양수': 20.237243842317575,
#  '계룡': 3.706852937628739,
#  '제로': 36.526204309757134,
#  '단독주택': 0.03257856502640712,
#  '신축': 61.29427306825892,
#  '수주': 401.2679276470661,
#  '전이': 4.264934006589814,
#  '주역': 6.062809312547714,
#  '화학': 223.43074082645515,
#  '스토리': 32.8515709542423,
#  '브레인': 22.168543054575157,
#  '콘텐츠': 91.13378692921223,
#  '사이클': 32.87345967761944,
#  '고도화': 3.8255054473636885,
#  '어가': 12.41030361758969,
#  '일주일': 16.070688468049067,
#  '전주': 13.647197134138983,
#  '서울시장': 2.8273217162153506,
#  '당선': -20.115971103607034,
#  '유력': 16.81477693713698,
#  '닷컴버블': 6.190252863639002,
#  '이후': 116.02236198059244,
#  '모주': 158.8590264868206,
#  '청약': 412.21273373569454,
#  ...}

# %% [markdown]
# # sent_score 설정

# %%
total = []

for i,w  in tqdm(enumerate(df['nouns'])) :
    sent_score = 0
    w = w.split(' ')
    
    for j in w :
        if len(j) <= 1 :
            continue
        elif j not in vocab :
            continue
        else :
            sent_score +=  vocab[j]
            
    total.append(sent_score / len(w))

df['sent_score'] = total
df.head()
# Out:
# 427673it [00:01, 216026.38it/s]
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
# 3 2021-01-04                    韓증시 사상최고치 시작  개장식선 안정적 시장운영에 방점 2021-01-05
# 4 2021-01-04                  SK바이오팜  아벨 지분 매각으로 5천500만 달러 자본이득 2021-01-05
#
#    등락률(y)  updown                           nouns   sent_score
# 0    2.24       1   비올 일본 최대 병원체 인과 실펌 엑스 판 계약 체결   200.719095
# 1    2.24       1                     환율 하락 전환 감소  1469.124320
# 2    2.24       1         코스피 오른 출발 원 달러 환율 오른 출발   791.474532
# 3    2.24       1  증시 사상 최고 치 시작 개장 선 안정 시장 운영 방점   309.554930
# 4    2.24       1            바이오 아벨 분 매각 달러 자본 이득   249.466333

# %%
desc = df['sent_score'].describe()
desc
# Out:
# count    427673.000000
# mean        408.715578
# std         368.245406
# min          -4.085983
# 25%         145.625767
# 50%         307.069524
# 75%         563.017385
# max        3875.347837
# Name: sent_score, dtype: float64

# %%
q3 = desc['75%']
q1 = desc['25%']

# %%
df['sent_label'] = 0

# %%
df.loc[df.query(f'sent_score >= {q3}').index, 'sent_label'] = 1 
df.loc[df.query(f'sent_score <= {q1}').index, 'sent_label'] = -1

# %%
df.head()
# Out:
#         Date                                              Title     주가의 날짜  \
# 0 2021-01-04                       비올  일본 최대 병원체인과 실펌엑스 총판계약 체결 2021-01-05
# 1 2021-01-04                           환율 하락 전환  1086 2 감소0 1원  2021-01-05
# 2 2021-01-04  코스피  1 03p 0 04   오른 2874 50 출발  원 달러 환율 1 2원 ... 2021-01-05
# 3 2021-01-04                    韓증시 사상최고치 시작  개장식선 안정적 시장운영에 방점 2021-01-05
# 4 2021-01-04                  SK바이오팜  아벨 지분 매각으로 5천500만 달러 자본이득 2021-01-05
#
#    등락률(y)  updown                           nouns   sent_score  sent_label
# 0    2.24       1   비올 일본 최대 병원체 인과 실펌 엑스 판 계약 체결   200.719095           0
# 1    2.24       1                     환율 하락 전환 감소  1469.124320           1
# 2    2.24       1         코스피 오른 출발 원 달러 환율 오른 출발   791.474532           1
# 3    2.24       1  증시 사상 최고 치 시작 개장 선 안정 시장 운영 방점   309.554930           0
# 4    2.24       1            바이오 아벨 분 매각 달러 자본 이득   249.466333           0

# %%
print(df['sent_label'].value_counts())
# Out:
#  0    213834
#  1    106920
# -1    106919
# Name: sent_label, dtype: int64

# %%
print(df['updown'].value_counts())
# Out:
#  0    169318
#  1    141094
# -1    117261
# Name: updown, dtype: int64

# %%
print(accuracy_score(df['updown'], df[ 'sent_label']))

#print(accuracy_score(df.loc[df.query('sent_label == 1').index, 'updown'],
#               df.loc[df.query('sent_label == 1').index, 'sent_label']))

#print(accuracy_score(df.loc[df.query('sent_label == -1').index, 'updown'],
#               df.loc[df.query('sent_label == -1').index, 'sent_label']))
# Out:
# 0.3505622286185941

# %% [markdown]
# # 트레인 테스트 분리¶

# %%
# X : title, y : price
def data_split(X, y) :
    
    # 학습셋, 테스트셋 분리
    X_list = X.tolist()
    y_list = y.tolist()
    
    X_train, X_test, y_train, y_test = train_test_split(X_list, y_list, shuffle = True, test_size = 0.2)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = data_split(df['Title'], df['sent_label'])

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 342138
# 85535

# %% [markdown]
# # 토큰화 및 로지스틱 회귀

# %%
# 형태소 분석을 위한 함수
def tokenizer(text):
    okt = Okt()
    return okt.morphs(text)

# %%
tokenize_X_train = TfidfVectorizer(tokenizer = tokenizer).fit_transform(X_train)
tokenize_X_test = TfidfVectorizer(tokenizer = tokenizer).fit_transform(X_test)

# %% [markdown]
# # 로지스틱 회귀 그리드 서치

# %%
def parameter_serach(penalty, solvers) :
    best_score = 0
    Cs = [0.001, 0.01, 0.1, 1, 10, 100]
        
    kfold = KFold(3, shuffle = True)

    for s in solvers :
        scores_mean = []
        for C in tqdm(Cs) :
            lm = LogisticRegression(penalty = penalty, C = C, solver = s, multi_class = 'multinomial')
            scores = cross_val_score(lm, tokenize_X_train, y_train, cv = kfold)

            score = np.mean(scores)
            scores_mean.append(score)

            if score > best_score:
                best_score = score
                best_parameters = {'penalty' : penalty, 'C': C, 'solver': s, 'best_score' : best_score}

    return best_parameters

# %%
# saga : 쓸 수 있지만 C값이 1 이상부터 시간이 너무 오래 걸림(몇분 단위)
#l1_best_parameters = parameter_serach('l1', ['saga'])

# %%
l2_best_parameters = parameter_serach('l2', ['lbfgs', 'newton-cg',  'sag', 'saga'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [04:25<00:00, 44.18s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [05:51<00:00, 58.66s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [01:45<00:00, 17.65s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [02:03<00:00, 20.62s/it]

# %% [markdown]
# ### 로지스틱 회귀의 최적 파라미터 확인

# %%
# print(f"penalty\t\t:\t{l1_best_parameters['penalty']}")
# print(f"C\t\t:\t{l1_best_parameters['C']}")
# print(f"solver\t\t:\t{l1_best_parameters['solver']}")
# print(f"best_score\t:\t{l1_best_parameters['best_score']}")

# %%
print(f"penalty\t\t:\t{l2_best_parameters['penalty']}")
print(f"C\t\t:\t{l2_best_parameters['C']}")
print(f"solver\t\t:\t{l2_best_parameters['solver']}")
print(f"best_score\t:\t{l2_best_parameters['best_score']}")
# Out:
# penalty		:	l2
# C		:	100
# solver		:	saga
# best_score	:	0.9497834207249706

# %%
# if l1_best_parameters['best_score'] > l2_best_parameters['best_score'] :
#     best_param = l1_best_parameters
# else :
#     best_param = l2_best_parameters

# %%
best_param = l2_best_parameters
best_param
# Out:
# {'penalty': 'l2', 'C': 100, 'solver': 'saga', 'best_score': 0.9497834207249706}

# %% [markdown]
# # 파이프 라인

# %%
# lowercase : 소문자로 반환 여부 lowercase = False, 
# tokenizer : 토크나이저 지정
tfidf = TfidfVectorizer(tokenizer = tokenizer)

# %%
logistic = LogisticRegression(penalty = best_param['penalty'],
                              C = best_param['C'],
                              solver = best_param['solver'],
                              multi_class = 'multinomial' )

# %%
pipeline = Pipeline([('tfidf',tfidf), ('classfier', logistic)], verbose = True)

# %%
pipeline.fit(X_train, y_train)
# Out:
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=12.2min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=  35.0s
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(tokenizer=<function tokenizer at 0x00000241DFDB5D30>)),
#                 ('classfier',
#                  LogisticRegression(C=100, multi_class='multinomial',
#                                     solver='saga'))],
#          verbose=True)

# %% [markdown]
# ### 교차검증

# %%
score = cross_val_score(pipeline, X_train, y_train, cv = KFold(3, shuffle = True), scoring='f1_micro')
# Out:
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total= 5.8min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=  19.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total= 5.2min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=  17.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total= 5.1min
# [Pipeline] ......... (step 2 of 2) Processing classfier, total=  19.7s

# %%
print(score)
print(f"모델의 정확도\t:\t{score.mean()}")
# Out:
# [0.94978342 0.94945022 0.95000263]
# 모델의 정확도	:	0.9497454243609305

# %%
y_pred = pipeline.predict(X_test)

# %%
y_proba = pipeline.predict_proba(X_test)

# %% [markdown]
# # 평가

# %%
print(f'accuracy \t:\t {accuracy_score(y_test, y_pred)}')

#'micro', 'macro', 'weighted'
print(f'f1_score \t:\t {f1_score(y_test, y_pred, average = "micro")}')
print(f'f1_score \t:\t {f1_score(y_test, y_pred, average = "macro")}')
print(f'f1_score \t:\t {f1_score(y_test, y_pred, average = "weighted")}')

print(f'R2 \t\t:\t {r2_score(y_test, y_pred)}')

print(f'mse \t\t:\t {mean_squared_error(y_test, y_pred)}')

print(f'rmse \t\t:\t {mean_squared_error(y_test, y_pred, squared=False)}')

print(f'log_loss\t:\t {log_loss(y_test, y_proba)}')
# Out:
# accuracy 	:	 0.959303209212603
# f1_score 	:	 0.959303209212603
# f1_score 	:	 0.9592475406616435
# f1_score 	:	 0.9593006877052767
# R2 		:	 0.9182593108832237
# mse 		:	 0.04080201087274215
# rmse 		:	 0.201995076357673
# log_loss	:	 0.11426404543775542

# %%
print(confusion_matrix(y_pred, y_test))
print(classification_report(y_pred, y_test))
# Out:
# [[20323   918     1]
#  [ 1012 41151   778]
#  [    2   770 20580]]
#               precision    recall  f1-score   support
#
#           -1       0.95      0.96      0.95     21242
#            0       0.96      0.96      0.96     42941
#            1       0.96      0.96      0.96     21352
#
#     accuracy                           0.96     85535
#    macro avg       0.96      0.96      0.96     85535
# weighted avg       0.96      0.96      0.96     85535

# %% [markdown]
# # 모델 저장 및 사용

# %%
def save_model(model) :
    with open('./[Model1]pipe_multi.dat', 'wb') as fp :     # 쓰기
        pickle.dump(model, fp)
    print('저장완료')     # 학습된 모델 저장 완료

# %%
save_model(pipeline)
# Out:
# 저장완료

# %%
with open('./[Model1]pipe_multi.dat','rb') as fp :     # 읽기
    pipeline = pickle.load(fp)

# %% [markdown]
# # Inference

# %%
# 모델 사용 함수

def model_prediction():  
    # 객체를 복원, 저장된 모델 불러오기
    with open('./[Model1]pipe_multi.dat','rb') as fp :     # 읽기
        pipe = pickle.load(fp)
    while True :
        text = input('뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) : \n')
        example = [text]
        # 예측 정확도
        r1 = np.max(pipe.predict_proba(example) * 100)     # 확률값을 구해서 *100
        
        # 예측 결과 
        r2 = pipe.predict(example)[0]     # 긍정(1), 중립(0), 부정(-1)

        if text == 'q' :
            print("예측을 종료합니다.")
            break
        if r2 == 1 :
            print(f'\n{stock_name} 주가가 상승할 것으로 예상됩니다.')
        elif r2 == -1 :
            print(f'\n{stock_name} 주가가 하락할 것으로 예상됩니다.')
        else : 
            print(f'\n모르겠어요.....')
        print('확률 : %.3f' % r1)
        print('------------------------------------------------\n')

# %%
model_prediction()
# Out:
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# [줌인 이종목] 현대중공업, 실적 증가 기대에 껑충
#
# 모르겠어요.....
# 확률 : 98.162
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# 닷새만에 반등했지만…불안한 개미들, 7100억 차익실현
#
# 모르겠어요.....
# 확률 : 98.962
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# 주식거래 뚝…"증권사, 2분기 실적 쇼크"
#
# 모르겠어요.....
# 확률 : 53.858
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# 20년 만의 '1유로=1달러'.. 경기침체 공포에 달러 초강세
#
# 모르겠어요.....
# 확률 : 99.994
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# 블랙록 '극심한 변동성' 경고.."지금은 저가매수도 하지 말라"
#
# 삼성SDI 주가가 하락할 것으로 예상됩니다.
# 확률 : 100.000
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# '현대차 효과' 부품株에도 볕드나.. 미래형 자동차 양산 기대감 호재 [현대차, 29년만에 국내공장 신설]
#
# 모르겠어요.....
# 확률 : 99.823
# ------------------------------------------------
#
# 뉴스 타이틀을 입력해주세요(종료를 원하시면 "q"를 입력해주세요) :
# q
# 예측을 종료합니다.

# %% [markdown]
# ```
# [줌인 이종목] 현대중공업, 실적 증가 기대에 껑충
# 닷새만에 반등했지만…불안한 개미들, 7100억 차익실현
# 주식거래 뚝…"증권사, 2분기 실적 쇼크"
# '현대차 효과' 부품株에도 볕드나.. 미래형 자동차 양산 기대감 호재 [현대차, 29년만에 국내공장 신설]
# 2차전지株, 실적 부진해도 상승하는 까닭
# 블랙록 '극심한 변동성' 경고.."지금은 저가매수도 하지 말라"
# 20년 만의 '1유로=1달러'.. 경기침체 공포에 달러 초강세
#
# ```
